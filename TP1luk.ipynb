# %%
# Importo librerias utilizadas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Leo el archivo properatti.csv
data = pd.read_csv('./properatti.csv')
print(f'Shape: {data.shape}')
data.head()
# Out:
# Shape: (121220, 26)
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# ...

# %%
# Porcentaje de nulls por columna
data.isnull().sum() / data.shape[0]
#data.isnull().sum()
# Out:
# Unnamed: 0                    0.000000
# operation                     0.000000
# property_type                 0.000000
# place_name                    0.000190
# place_with_parent_names       0.000000
# country_name                  0.000000
# state_name                    0.000000
# geonames_id                   0.154405
# lat-lon                       0.425260
# lat                           0.425260
# lon                           0.425260
# price                         0.168372
# currency                      0.168380
# price_aprox_local_currency    0.168372
# price_aprox_usd               0.168372
# surface_total_in_m2           0.324435
# surface_covered_in_m2         0.164222
# price_usd_per_m2              0.433947
# price_per_m2                  0.276869
# floor                         0.934837
# rooms                         0.609058
# expenses                      0.882346
# properati_url                 0.000000
# description                   0.000016
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                         0
# operation                          0
# property_type                      0
# place_name                        23
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    18717
# lat-lon                        51550
# lat                            51550
# lon                            51550
# price                          20410
# currency                       20411
# price_aprox_local_currency     20410
# price_aprox_usd                20410
# surface_total_in_m2            39328
# surface_covered_in_m2          19907
# price_usd_per_m2               52603
# price_per_m2                   33562
# floor                         113321
# rooms                          73830
# expenses                      106958
# properati_url                      0
# description                        2
# title                              0
# ...

# %%
# Valores de operation
data.operation.value_counts()
# Out:
# sell    121220
# Name: operation, dtype: int64

# %%
# Valores de property_type
data.property_type.value_counts()
# Out:
# apartment    71065
# house        40268
# PH            5751
# store         4136
# Name: property_type, dtype: int64

# %%
sns.histplot( x="property_type", data=data, hue='property_type' )
plt.show()

# %%
# Valores de property_type
data.place_name.value_counts()

#hay que asignarle tigre
data[data.place_name.isnull()]

data[data.place_name == 'Tigre']
# Out:
#         Unnamed: 0 operation property_type place_name  \
# 18              18      sell         house      Tigre
# 237            237      sell         house      Tigre
# 239            239      sell         house      Tigre
# 387            387      sell         house      Tigre
# 410            410      sell         house      Tigre
# ...            ...       ...           ...        ...
# 120949      120949      sell         house      Tigre
# 120951      120951      sell         house      Tigre
# 121089      121089      sell         house      Tigre
# 121104      121104      sell            PH      Tigre
# 121118      121118      sell     apartment      Tigre
#
#                                  place_with_parent_names country_name  \
# 18            |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 237           |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 239           |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# ...

# %%
data.place_with_parent_names.value_counts()
# Out:
# |Argentina|Santa Fe|Rosario|                                        8504
# |Argentina|Córdoba|Córdoba|                                         6606
# |Argentina|Buenos Aires Costa Atlántica|Mar del Plata|              6534
# |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nordelta|                 3315
# |Argentina|Capital Federal|Belgrano|                                2992
#                                                                     ...
# |Argentina|Entre Ríos|Villa Paranacito|                                1
# |Argentina|San Juan|Villa Mercedes|                                    1
# |Argentina|Buenos Aires Interior|Chascomús|Barrio Parque Girado|       1
# |Argentina|Buenos Aires Costa Atlántica|Mar del Plata|Alfar|           1
# |Argentina|Bs.As. G.B.A. Zona Sur|Berazategui|Altos de Hudson I|       1
# Name: place_with_parent_names, Length: 1164, dtype: int64

# %%
data.country_name.value_counts()
# Out:
# Argentina    121220
# Name: country_name, dtype: int64

# %%
data.state_name.value_counts()
# Out:
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Río Negro                         808
# Neuquén                           733
# Mendoza                           681
# Tucumán                           674
# Corrientes                        583
# Misiones                          464
# Entre Ríos                        369
# Salta                             278
# Chubut                            259
# San Luis                          252
# La Pampa                          157
# Formosa                            65
# Chaco                              57
# San Juan                           40
# Tierra Del Fuego                   31
# Catamarca                          27
# Jujuy                              26
# ...

# %%
mask = data['place_name'] == 'Palermo Hollywood'
mask2 = data['geonames_id'].notnull()
data.loc[mask & mask2, ['place_name','state_name','geonames_id']]

#mask = data['geonames_id'].isnull()
#data.loc[mask,['place_name','state_name','geonames_id']]
# Out:
# Empty DataFrame
# Columns: [place_name, state_name, geonames_id]
# Index: []

# %%
#Verificamos lat-lon , lat y lon
data.iloc[:,3:11]
mask = data['lat'].isnull()
mask2 = data['lon'].isnull()
mask3 = data['lat-lon'].isnull()

data.loc[mask & mask2 & mask3]
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 13              13      sell     apartment     Palermo Soho
# 14              14      sell     apartment     Palermo Soho
# 23              23      sell     apartment            Pilar
# 42              42      sell         house            Pilar
# 49              49      sell         house          Escobar
# ...            ...       ...           ...              ...
# 121214      121214      sell         store       San Isidro
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 13       |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 14       |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# ...

# %%
#data.iloc[:, 11:15]
#data.currency.value_counts()
mask = data['currency'] == 'ARS'
data.columns
data.loc[mask,['price','currency','price_aprox_local_currency','price_aprox_usd']]
data['pesos'] = data['price_aprox_local_currency'] / data['price_aprox_usd']
data['pesos'].value_counts()

mask1 = data['price'].isnull()
mask2 = data['price_aprox_local_currency'].isnull()
mask3 = data['price_aprox_usd'].isnull()
data.loc[mask1 & mask2 & mask3,['price','currency','price_aprox_local_currency','price_aprox_usd']]
# Out:
#         price currency  price_aprox_local_currency  price_aprox_usd
# 5         NaN      NaN                         NaN              NaN
# 20        NaN      NaN                         NaN              NaN
# 41        NaN      NaN                         NaN              NaN
# 62        NaN      NaN                         NaN              NaN
# 67        NaN      NaN                         NaN              NaN
# ...       ...      ...                         ...              ...
# 121210    NaN      NaN                         NaN              NaN
# 121211    NaN      NaN                         NaN              NaN
# 121212    NaN      NaN                         NaN              NaN
# 121213    NaN      NaN                         NaN              NaN
# 121214    NaN      NaN                         NaN              NaN
#
# [20410 rows x 4 columns]

# %%
data.columns
mask1 = data['price'].isnull()
mask2 = data['price_usd_per_m2'].isnull()
mask3 = data['price_per_m2'].isnull()
data.loc[mask1 & mask2 & mask3,['price','price_usd_per_m2','price_per_m2']]
# Out:
#         price  price_usd_per_m2  price_per_m2
# 5         NaN               NaN           NaN
# 20        NaN               NaN           NaN
# 41        NaN               NaN           NaN
# 62        NaN               NaN           NaN
# 67        NaN               NaN           NaN
# ...       ...               ...           ...
# 121210    NaN               NaN           NaN
# 121211    NaN               NaN           NaN
# 121212    NaN               NaN           NaN
# 121213    NaN               NaN           NaN
# 121214    NaN               NaN           NaN
#
# [20410 rows x 3 columns]

# %%
data.columns
mask1 = data['surface_total_in_m2'].isnull()
mask2 = data['surface_covered_in_m2'].isnull()
data.loc[mask1 & mask2,['price','price_usd_per_m2','price_per_m2']]
# Out:
#            price  price_usd_per_m2  price_per_m2
# 1       150000.0               NaN           NaN
# 3        95000.0               NaN           NaN
# 9       460000.0               NaN           NaN
# 11      150000.0               NaN           NaN
# 65       50000.0               NaN           NaN
# ...          ...               ...           ...
# 121086       NaN               NaN           NaN
# 121101  370000.0               NaN           NaN
# 121133  110000.0               NaN           NaN
# 121134  250000.0               NaN           NaN
# 121144  350000.0               NaN           NaN
#
# [12369 rows x 3 columns]

# %%
maskCasa = data['property_type'] == 'apartment'
maskFloor = data['floor'] > 0
data.loc[maskCasa & maskFloor,['property_type','floor']]



data[(data['floor'] > 1) & (data['property_type'] == 'house')].description
sns.scatterplot(data=data, x='property_type', y="price_per_m2")


data[['description','floor']]
# Out:
#                                               description  floor
# 0       2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...    NaN
# 1       Venta de departamento en décimo piso al frente...    NaN
# 2       2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...    NaN
# 3       PH 3 ambientes con patio. Hay 3 deptos en lote...    NaN
# 4       DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...    NaN
# ...                                                   ...    ...
# 121215  TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...    NaN
# 121216  Excelente e impecable casa en Venta en Las Lom...    NaN
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...    NaN
# 121218  2 Amb al contrafrente,  luminoso. El departame...    NaN
# 121219  Departamento de 77 m2 apto profesional. Edific...    NaN
#
# [121220 rows x 2 columns]

# %%
sns.scatterplot(data=data, x='property_type', y="price_per_m2")
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_per_m2'>

# %%
#hay outliers dependiendo de la superficie total?
sns.scatterplot(data=data, x='property_type', y="surface_total_in_m2", hue='property_type')
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='surface_total_in_m2'>

# %%
#casas --> fincas? 
mask1 = data['property_type'] == 'house'
mask2 = data['surface_total_in_m2'] > 40000
data.loc[mask1 & mask2]
# Out:
#        Unnamed: 0 operation property_type                place_name  \
# 509           509      sell         house          Belén de Escobar
# 2979         2979      sell         house               Punta Indio
# 8758         8758      sell         house                   Miramar
# 35226       35226      sell         house          Coronel Brandsen
# 44236       44236      sell         house                San Isidro
# 44246       44246      sell         house                    Zárate
# 50693       50693      sell         house         General Rodríguez
# 53312       53312      sell         house  San Antonio de Arredondo
# 53313       53313      sell         house  San Antonio de Arredondo
# 53314       53314      sell         house  San Antonio de Arredondo
# 71991       71991      sell         house          Coronel Brandsen
#
#                                  place_with_parent_names country_name  \
# 509    |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|Be...    Argentina
# ...

# %%
#hay outliers dependiendo de la superficie cubierta?
sns.scatterplot(data=data, x='property_type', y="surface_covered_in_m2", hue='property_type')
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='surface_covered_in_m2'>

# %%
mask1 = data['property_type'] == 'apartment'
mask2 = data['surface_covered_in_m2'] > 300
data.loc[mask1 & mask2][['surface_total_in_m2','surface_covered_in_m2','description']]
# Out:
#         surface_total_in_m2  surface_covered_in_m2  \
# 177                   420.0                  450.0
# 876                     NaN                  382.0
# 877                     NaN                  472.0
# 1143                  309.0                  309.0
# 1276                  529.0                  431.0
# ...                     ...                    ...
# 118681                370.0                  370.0
# 119253                  NaN                 1000.0
# 119348                400.0                  400.0
# 119355                  NaN                 1300.0
# 119408                389.0                  337.0
#
#                                               description
# 177     CASA PRINCIPAL QUE CONSTA DE 3 DORM,.AMPLIOS,2...
# 876     Corredor Responsable: Mario Gabriel Gerez - CU...
# 877     Corredor Responsable: Mario Gabriel Gerez - CU...
# 1143    Excelente piso antiguo de estilo racionalista,...
# ...

# %%
#rango intercuartil [(Q3 - Q1) * 1.5] + Q3 = OUTLAYER --> regex en description para verificar? --> 
mask1 = data['property_type'] == 'apartment'
data.loc[mask1][['surface_total_in_m2','surface_covered_in_m2','description']].describe()

# [(Q3 - Q1) * 1.5] + Q3 = 130m2
# Q1 - [(Q3 - Q1) * 1.5] = -x
# Out:
#        surface_total_in_m2  surface_covered_in_m2
# count         51085.000000           59735.000000
# mean             96.605873              74.039173
# std            1602.658969             805.139125
# min               0.000000               0.000000
# 25%              43.000000              40.000000
# 50%              59.000000              52.000000
# 75%              87.000000              76.000000
# max          200000.000000          187000.000000

# %%
#Departamentos con menos de 15m2
mask1 = data['property_type'] == 'apartment'
mask2 = data['surface_covered_in_m2'] < 15
data.loc[mask1 & mask2][['surface_covered_in_m2']]
# Out:
#         surface_covered_in_m2
# 349                       1.0
# 840                       4.0
# 1775                     10.0
# 1845                      1.0
# 2265                      1.0
# ...                       ...
# 112288                    8.0
# 112998                    7.0
# 112999                   10.0
# 116947                    1.0
# 119165                    1.0
#
# [221 rows x 1 columns]

# %%
#hay outliers dependiendo del price_aprox_usd?
sns.scatterplot(data=data, x='property_type', y="price_aprox_usd", hue='property_type')
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='price_aprox_usd'>

# %%
mask1 = data['property_type'] == 'apartment'
mask2 = data['price_aprox_usd'] < 1
data.loc[mask1 & mask2][['price_aprox_usd','description']]
# Out:
# Empty DataFrame
# Columns: [price_aprox_usd, description]
# Index: []

# %%
mask1 = data['property_type'] == 'apartment'
data.loc[mask1][['price_aprox_usd',]].describe()

# [(Q3 - Q1) * 1.5] + Q3 = 355000
# Q1 - [(Q3 - Q1) * 1.5] = -x
# Out:
#        price_aprox_usd
# count     5.961600e+04
# mean      1.874069e+05
# std       3.162183e+05
# min       4.666620e+03
# 25%       8.000000e+04
# 50%       1.190000e+05
# 75%       1.900000e+05
# max       4.654544e+07

# %%
mask1 = data['surface_total_in_m2'] < data['surface_covered_in_m2']
data[mask1][['surface_total_in_m2','surface_covered_in_m2']]
#data['sospechosos'] = data[mask1] # --> revisar
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lucas\anaconda3\envs\DH\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Users\Lucas\anaconda3\envs\DH\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Lucas\anaconda3\envs\DH\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sospechosos'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# houses --> pasar a dummy/nueva columna si son fincas/cacras por m2

# %%
data.rooms.value_counts()
# Out:
# 3.0     12567
# 2.0     12433
# 4.0      7937
# 1.0      7377
# 5.0      3782
# 6.0      1403
# 7.0       770
# 8.0       409
# 10.0      226
# 9.0       184
# 11.0       72
# 12.0       65
# 13.0       33
# 14.0       27
# 15.0       26
# 17.0       16
# 16.0       11
# 20.0       11
# 22.0        8
# 18.0        6
# 21.0        5
# 19.0        4
# 30.0        4
# 25.0        4
# 32.0        3
# 23.0        2
# 24.0        1
# 31.0        1
# 29.0        1
# 27.0        1
# 28.0        1
# Name: rooms, dtype: int64

# %%
display (data.pivot_table(["country_name"],"rooms","property_type", aggfunc="count"))
# Out:
#               country_name
# property_type           PH apartment   house store
# rooms
# 1.0                  118.0    6940.0   264.0  55.0
# 2.0                  744.0   10664.0  1008.0  17.0
# 3.0                 1301.0    7946.0  3307.0  13.0
# 4.0                  705.0    3867.0  3361.0   4.0
# 5.0                  263.0    1162.0  2353.0   4.0
# 6.0                   69.0     330.0  1002.0   2.0
# 7.0                   24.0     174.0   566.0   6.0
# 8.0                   10.0      86.0   312.0   1.0
# 9.0                    5.0      34.0   145.0   NaN
# 10.0                   4.0      22.0   197.0   3.0
# 11.0                   1.0       9.0    62.0   NaN
# 12.0                   1.0      12.0    52.0   NaN
# 13.0                   1.0       3.0    29.0   NaN
# 14.0                   NaN       5.0    22.0   NaN
# 15.0                   NaN       2.0    24.0   NaN
# 16.0                   NaN       NaN    11.0   NaN
# 17.0                   NaN       3.0    13.0   NaN
# ...

# %%
display (data.pivot_table(["country_name"],"floor","property_type", aggfunc="count"))
# Out:
#               country_name
# property_type           PH apartment  house store
# floor
# 1.0                  154.0    1517.0  385.0  24.0
# 2.0                  146.0    1096.0  290.0  10.0
# 3.0                   63.0     833.0   18.0   NaN
# 4.0                   31.0     625.0    1.0   1.0
# 5.0                   38.0     444.0    2.0   NaN
# ...                    ...       ...    ...   ...
# 1609.0                 NaN       4.0    NaN   NaN
# 2103.0                 NaN       1.0    NaN   NaN
# 2177.0                 NaN       NaN    1.0   NaN
# 2509.0                 NaN       1.0    NaN   NaN
# 3150.0                 NaN       NaN    1.0   NaN
#
# [182 rows x 4 columns]

# %%
data[data['floor'] == 3150]
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 39394       39394      sell         house     Nogoyá
#
#              place_with_parent_names country_name  state_name  geonames_id  \
# 39394  |Argentina|Entre Ríos|Nogoyá|    Argentina  Entre Ríos    3430412.0
#
#                        lat-lon       lat  ...  price_usd_per_m2  price_per_m2  \
# 39394  -32.3977301,-59.7901354 -32.39773  ...               NaN           NaN
#
#         floor  rooms  expenses  \
# 39394  3150.0    5.0       NaN
#
#                                            properati_url  \
# 39394  http://www.properati.com.ar/18o8m_venta_casa_n...
#
#                                              description          title  \
# 39394  Amplia casa con local en pleno centro a una cu...  CASA EN VENTA
#
#                                          image_thumbnail  pesos
# 39394  https://thumbs4.properati.com/5/03IWlqTkvN9OYg...    NaN
#
# [1 rows x 27 columns]

# %%
#Hay nombres de place_name que tiene espacios al principio/final del string
data['place_name'] = data['place_name'].apply(lambda x : str(x).strip())

# %%
data.columns
mask1 = data['expenses'].isnull()
mask2 = data['property_type'] == 'apartment'
data.loc[mask1 & mask2]
# Out:
#         Unnamed: 0 operation property_type     place_name  \
# 1                1      sell     apartment       La Plata
# 2                2      sell     apartment      Mataderos
# 4                4      sell     apartment         Centro
# 7                7      sell     apartment       Belgrano
# 8                8      sell     apartment       Belgrano
# ...            ...       ...           ...            ...
# 121205      121205      sell     apartment        Córdoba
# 121206      121206      sell     apartment        Córdoba
# 121211      121211      sell     apartment       Acassuso
# 121217      121217      sell     apartment  Villa Urquiza
# 121218      121218      sell     apartment    Plaza Colón
#
#                                   place_with_parent_names country_name  \
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# ...

# %%
data_property_type = data.groupby(['place_name','state_name'],dropna=False)
#print(data_property_type.size())
#print(data_property_type.size().sum())
#print(data_property_type.size().sum() / data.shape[0])

data_property_type.count()
#non_numeric_columns = list(set(data.columns)-set(data._get_numeric_data().columns))
#data[non_numeric_columns] = data[non_numeric_columns].apply(lambda x : str(x).strip())
# Out:
#                                                   Unnamed: 0  operation  \
# place_name              state_name
#  Country Maschwitz Club Bs.As. G.B.A. Zona Norte           3          3
#  los alamos             Bs.As. G.B.A. Zona Norte           1          1
# 9 de Abril              Bs.As. G.B.A. Zona Sur             3          3
# Abasto                  Bs.As. G.B.A. Zona Sur            26         26
#                         Capital Federal                  113        113
# ...                                                      ...        ...
# Zelaya                  Bs.As. G.B.A. Zona Norte           7          7
# Zárate                  Buenos Aires Interior             15         15
# coordenadas 34.255511   Bs.As. G.B.A. Zona Norte           1          1
# Álvarez                 Santa Fe                           1          1
# NaN                     Bs.As. G.B.A. Zona Norte          23         23
#
#                                                   property_type  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'pesos'],
#       dtype='object')

# %%
# Chequeo si todos los place_names son correctos en place_with_parent_names.
# 23 faltan
place_coincide = data.apply(lambda x: True if str(x['place_with_parent_names']).find(str(x['place_name'])) >= 0 else False, axis=1)
place_coincide.value_counts()
# Out:
# True     121197
# False        23
# dtype: int64

# %%
place_name_missing = pd.isnull(data['place_name'])
data['place_name'] = data[place_name_missing].apply(lambda x: str(x['place_with_parent_names'].split('|')[3]) if (pd.isna(x['place_name']) | pd.isnull(x['place_name'])) else x['place_name'], axis=1)

# %%
place_name_missing = pd.isnull(data['place_name'])
data[place_name_missing]
# Out:
#         Unnamed: 0 operation property_type place_name  \
# 0                0      sell            PH        NaN
# 1                1      sell     apartment        NaN
# 2                2      sell     apartment        NaN
# 3                3      sell            PH        NaN
# 4                4      sell     apartment        NaN
# ...            ...       ...           ...        ...
# 121215      121215      sell     apartment        NaN
# 121216      121216      sell         house        NaN
# 121217      121217      sell     apartment        NaN
# 121218      121218      sell     apartment        NaN
# 121219      121219      sell     apartment        NaN
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# ...

# %%
# Chequeo si todos los state_names son correctos en place_with_parent_names
state_coincide = data.apply(lambda x: True if str(x['place_with_parent_names']).find(str(x['state_name'])) >= 0 else False, axis=1)
state_coincide.value_counts()
# Out:
# True    121220
# dtype: int64

# %%
# Chequeo si todos los country_names son correctos en place_with_parent_names
country_coincide = data.apply(lambda x: True if str(x['place_with_parent_names']).find(str(x['country_name'])) >= 0 else False, axis=1)
country_coincide.value_counts()
# Out:
# True    121220
# dtype: int64

# %%
data.columns
data_grouped = data.groupby(['state_name'])
display(data_grouped.describe().sort_values(by=('price_aprox_usd','mean'), ascending=False)['price_aprox_usd'].round)
# Out:
# <bound method DataFrame.round of                                 count           mean           std       min  \
# state_name
# Catamarca                        26.0  725471.707308  5.631223e+05  72908.77
# Chubut                          164.0  342338.181524  6.230407e+05   8412.55
# Bs.As. G.B.A. Zona Norte      24058.0  324317.123170  3.772690e+05   5047.53
# Salta                           102.0  312755.743529  6.657355e+05  29163.51
# Jujuy                            10.0  301584.442000  3.208568e+05  47671.12
# Río Negro                       361.0  300126.180693  8.746507e+05  16825.10
# San Juan                          4.0  299575.820000  2.816914e+05  26249.78
# San Luis                        208.0  282242.500433  5.167827e+05  36454.38
# Capital Federal               29018.0  269603.182879  4.575790e+05   5103.61
# Mendoza                         476.0  249705.485588  1.068573e+06   8973.38
# Neuquén                         324.0  219429.090401  3.296495e+05   5608.36
# ...

# %%
data_grouped_place_name = data.groupby(['place_name'],dropna=False)
data_grouped_place_name.count()
# Out:
#             Unnamed: 0  operation  property_type  place_with_parent_names  \
# place_name
# Tigre               23         23             23                       23
# NaN             121197     121197         121197                   121197
#
#             country_name  state_name  geonames_id  lat-lon    lat    lon  ...  \
# place_name                                                                ...
# Tigre                 23          23            0       23     23     23  ...
# NaN               121197      121197       102503    69647  69647  69647  ...
#
#             price_usd_per_m2  price_per_m2  floor  rooms  expenses  \
# place_name
# Tigre                     18            23      0      8         0
# NaN                    68599         87635   7899  47382     14262
#
#             properati_url  description   title  image_thumbnail   pesos
# place_name
# Tigre                  23           23      23               23      23
# ...
