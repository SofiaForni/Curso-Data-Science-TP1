# %%
# Importo librerias utilizadas
import pandas as pd
import seaborn as sns

# %%
# Leo el archivo properatti.csv
data = pd.read_csv('properatti\properatti.csv')
print(f'Shape: {data.shape}')
data.head()
# Out:
# Shape: (121220, 26)
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat  ...  surface_covered_in_m2  price_usd_per_m2 price_per_m2  \
# 0 -34.661824  ...                   40.0       1127.272727  1550.000000
# 1 -34.903883  ...                    NaN               NaN          NaN
# 2 -34.652262  ...                   55.0       1309.090909  1309.090909
# 3 -34.647797  ...                    NaN               NaN          NaN
# 4 -38.002626  ...                   35.0       1828.571429  1828.571429
#
#    floor  rooms  expenses                                      properati_url  \
# 0    NaN    NaN       NaN  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1    NaN    NaN       NaN  http://www.properati.com.ar/15bob_venta_depart...
# 2    NaN    NaN       NaN  http://www.properati.com.ar/15bod_venta_depart...
# 3    NaN    NaN       NaN  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4    NaN    NaN       NaN  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...
#
# [5 rows x 26 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0                      int64
# operation                      object
# property_type                  object
# place_name                     object
# place_with_parent_names        object
# country_name                   object
# state_name                     object
# geonames_id                   float64
# lat-lon                        object
# lat                           float64
# lon                           float64
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# description                    object
# title                          object
# image_thumbnail                object
# dtype: object

# %%
# Porcentaje de nulls por columna
data.isnull().sum() / data.shape[0]
#data.isnull().sum()
# Out:
# Unnamed: 0                    0.000000
# operation                     0.000000
# property_type                 0.000000
# place_name                    0.000190
# place_with_parent_names       0.000000
# country_name                  0.000000
# state_name                    0.000000
# geonames_id                   0.154405
# lat-lon                       0.425260
# lat                           0.425260
# lon                           0.425260
# price                         0.168372
# currency                      0.168380
# price_aprox_local_currency    0.168372
# price_aprox_usd               0.168372
# surface_total_in_m2           0.324435
# surface_covered_in_m2         0.164222
# price_usd_per_m2              0.433947
# price_per_m2                  0.276869
# floor                         0.934837
# rooms                         0.609058
# expenses                      0.882346
# properati_url                 0.000000
# description                   0.000016
# title                         0.000000
# image_thumbnail               0.025672
# dtype: float64

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                         0
# operation                          0
# property_type                      0
# place_name                        23
# place_with_parent_names            0
# country_name                       0
# state_name                         0
# geonames_id                    18717
# lat-lon                        51550
# lat                            51550
# lon                            51550
# price                          20410
# currency                       20411
# price_aprox_local_currency     20410
# price_aprox_usd                20410
# surface_total_in_m2            39328
# surface_covered_in_m2          19907
# price_usd_per_m2               52603
# price_per_m2                   33562
# floor                         113321
# rooms                          73830
# expenses                      106958
# properati_url                      0
# description                        2
# title                              0
# image_thumbnail                 3112
# dtype: int64

# %%
# Valores de operation
data.operation.value_counts()
# Out:
# sell    121220
# Name: operation, dtype: int64

# %%
# Valores de property_type
tipo_de_propiedad_todos=data.property_type.value_counts()
tipo_de_propiedad_todos
# Out:
# apartment    71065
# house        40268
# PH            5751
# store         4136
# Name: property_type, dtype: int64

# %%
data_cap_fed=data.state_name=="Capital Federal"
data[data_cap_fed]["property_type"].value_counts()
# Out:
# apartment    27037
# house         2087
# PH            1828
# store         1364
# Name: property_type, dtype: int64

# %%
data_gba=(data.state_name=="Bs.As. G.B.A. Zona Sur")|(data.state_name=="Bs.As. G.B.A. Zona Oeste")|(data.state_name=="Bs.As. G.B.A. Zona Norte")
data[data_gba]["property_type"].value_counts()
# Out:
# house        25012
# apartment    19747
# PH            2595
# store         1480
# Name: property_type, dtype: int64

# %%
data_amba=(data_cap_fed)|(data_gba)
tipo_de_propiedad_amba=data[data_amba]["property_type"].value_counts()
tipo_de_propiedad_amba
# Out:
# apartment    46784
# house        27099
# PH            4423
# store         2844
# Name: property_type, dtype: int64

# %%
todos=tipo_de_propiedad_todos.sort_index
amba=tipo_de_propiedad_amba.sort_index
porcentaje_amba=tipo_de_propiedad_amba/tipo_de_propiedad_todos
porcentaje_amba
#Prácticamente 2/3 de la muestra es del AMBA.
# Out:
# apartment    0.658327
# house        0.672966
# PH           0.769084
# store        0.687621
# Name: property_type, dtype: float64

# %%
data_rosario=data.place_name=="Rosario"
data_cordoba=data.place_name=="Córdoba"

# %%
tipo_de_propiedad_cordoba=data[data_cordoba]["property_type"].value_counts()
tipo_de_propiedad_cordoba
cordoba=tipo_de_propiedad_cordoba.sort_index
porcentaje_cordoba=tipo_de_propiedad_cordoba/tipo_de_propiedad_todos
porcentaje_cordoba
#Esto se debe poder hacer para todos los lugares juntos pero no tengo ganas de pensar cómo en este momento.
# Out:
# PH           0.061033
# apartment    0.084106
# house        0.063251
# store        0.091634
# Name: property_type, dtype: float64

# %%
tipo_de_propiedad_rosario=data[data_rosario]["property_type"].value_counts()
tipo_de_propiedad_rosario
cordoba=tipo_de_propiedad_rosario.sort_index
porcentaje_rosario=tipo_de_propiedad_rosario/tipo_de_propiedad_todos
porcentaje_rosario
#Esto se debe poder hacer para todos los lugares juntos pero no tengo ganas de pensar cómo en este momento.
# Out:
# PH           0.011476
# apartment    0.104608
# house        0.020835
# store        0.039894
# Name: property_type, dtype: float64

# %%
tipo_de_propiedad_rosario_df=pd.DataFrame(tipo_de_propiedad_rosario)
tipo_de_propiedad_cordoba_df=pd.DataFrame(tipo_de_propiedad_cordoba)
tipo_de_propiedad_amba_df=pd.DataFrame(tipo_de_propiedad_amba)
tipo_de_propiedad_todos_df=pd.DataFrame(tipo_de_propiedad_todos)
tipo_de_propiedad_porcentajes_df=tipo_de_propiedad_amba_df.join(tipo_de_propiedad_todos_df,how="inner",lsuffix="amba",rsuffix="todos")
tipo_de_propiedad_porcentajes_df=tipo_de_propiedad_porcentajes_df.join(tipo_de_propiedad_rosario_df,how="inner")
#Buscar como renombrar property_type para que diga Rosario.
tipo_de_propiedad_porcentajes_df=tipo_de_propiedad_porcentajes_df.join(tipo_de_propiedad_cordoba_df,how="inner",rsuffix="cordoba")

tipo_de_propiedad_porcentajes_df
#tipo_de_propiedad_porcentajes_df["porcentaje_rosario"]=tipo_de_propiedad_porcentajes_df["property_type"]/tipo_de_propiedad_porcentajes_df["property_typetodos"]
# Out:
#            property_typeamba  property_typetodos  property_type  \
# apartment              46784               71065           7434
# house                  27099               40268            839
# PH                      4423                5751             66
# store                   2844                4136            165
#
#            property_typecordoba
# apartment                  5977
# house                      2547
# PH                          351
# store                       379

# %%
#tipo_de_propiedad_porcentajes_df["property_type"]/tipo_de_propiedad_porcentajes_df["property_typetodos"]
for i in tipo_de_propiedad_porcentajes_df.columns:
    tipo_de_propiedad_porcentajes_df["porcentaje"+i]=tipo_de_propiedad_porcentajes_df[i]/tipo_de_propiedad_porcentajes_df["property_typetodos"]
tipo_de_propiedad_porcentajes_df
# Out:
#            property_typeamba  property_typetodos  property_type  \
# apartment              46784               71065           7434
# house                  27099               40268            839
# PH                      4423                5751             66
# store                   2844                4136            165
#
#            property_typecordoba  porcentajeproperty_typeamba  \
# apartment                  5977                     0.658327
# house                      2547                     0.672966
# PH                          351                     0.769084
# store                       379                     0.687621
#
#            porcentajeproperty_typetodos  porcentajeproperty_type  \
# apartment                           1.0                 0.104608
# house                               1.0                 0.020835
# PH                                  1.0                 0.011476
# store                               1.0                 0.039894
#
#            porcentajeproperty_typecordoba
# apartment                        0.084106
# house                            0.063251
# PH                               0.061033
# store                            0.091634

# %%
#precio_m2 = data.apply(lambda x: 0 if x['Landsize'] == 0 else x['Price'] / x['Landsize'], axis=1)

tipo_de_propiedad_porcentajes_df["porcentaje_amba"]=tipo_de_propiedad_porcentajes_df.apply(lambda x: x["property_typeamba"]/x["property_typetodos"],axis=1)
tipo_de_propiedad_porcentajes_df
# Out:
#            property_typeamba  property_typetodos  property_type  \
# apartment              46784               71065           7434
# house                  27099               40268            839
# PH                      4423                5751             66
# store                   2844                4136            165
#
#            property_typecordoba  porcentajeproperty_typeamba  \
# apartment                  5977                     0.658327
# house                      2547                     0.672966
# PH                          351                     0.769084
# store                       379                     0.687621
#
#            porcentajeproperty_typetodos  porcentajeproperty_type  \
# apartment                           1.0                 0.104608
# house                               1.0                 0.020835
# PH                                  1.0                 0.011476
# store                               1.0                 0.039894
#
#            porcentajeproperty_typecordoba  porcentaje_amba
# apartment                        0.084106         0.658327
# house                            0.063251         0.672966
# PH                               0.061033         0.769084
# store                            0.091634         0.687621

# %%
data[data["geonames_id"].isnull()]["place_name"].isnull().sum()
#Todos los que no tienen geonames_id, de todos modos tienen el place_name.
# Out:
# 23

# %%
# Valores de property_type
data.place_name.value_counts()

#hay que asignarle tigre
data[data.place_name.isnull()]

data[data.place_name == 'Tigre']
# Out:
#         Unnamed: 0 operation property_type place_name  \
# 18              18      sell         house      Tigre
# 237            237      sell         house      Tigre
# 239            239      sell         house      Tigre
# 387            387      sell         house      Tigre
# 410            410      sell         house      Tigre
# ...            ...       ...           ...        ...
# 120949      120949      sell         house      Tigre
# 120951      120951      sell         house      Tigre
# 121089      121089      sell         house      Tigre
# 121104      121104      sell            PH      Tigre
# 121118      121118      sell     apartment      Tigre
#
#                                  place_with_parent_names country_name  \
# 18            |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 237           |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 239           |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 387           |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 410     |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Tigre|    Argentina
# ...                                                  ...          ...
# 120949        |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 120951        |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 121089        |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 121104        |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 121118        |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 18      Bs.As. G.B.A. Zona Norte    3427753.0         -34.425087,-58.5796585
# 237     Bs.As. G.B.A. Zona Norte    3427753.0  -34.3797634778,-58.6778488076
# 239     Bs.As. G.B.A. Zona Norte    3427753.0  -34.3806135197,-58.6860885537
# 387     Bs.As. G.B.A. Zona Norte    3427753.0        -34.3714273,-58.6793104
# 410     Bs.As. G.B.A. Zona Norte          NaN         -34.379324,-58.7177185
# ...                          ...          ...                            ...
# 120949  Bs.As. G.B.A. Zona Norte    3427753.0                            NaN
# 120951  Bs.As. G.B.A. Zona Norte    3427753.0                            NaN
# 121089  Bs.As. G.B.A. Zona Norte    3427753.0                            NaN
# 121104  Bs.As. G.B.A. Zona Norte    3427753.0                            NaN
# 121118  Bs.As. G.B.A. Zona Norte    3427753.0                            NaN
#
#               lat  ...  surface_covered_in_m2  price_usd_per_m2 price_per_m2  \
# 18     -34.425087  ...                  270.0       2111.111111  2111.111111
# 237    -34.379763  ...                  300.0       1400.000000  1400.000000
# 239    -34.380614  ...                  300.0       1400.000000  1400.000000
# 387    -34.371427  ...                  200.0        433.333333  1950.000000
# 410    -34.379324  ...                  220.0        405.555556  1659.090909
# ...           ...  ...                    ...               ...          ...
# 120949        NaN  ...                  228.0       1754.385965  1754.385965
# 120951        NaN  ...                  193.0       1524.163569  2124.352332
# 121089        NaN  ...                  167.0       1415.094340  1796.407186
# 121104        NaN  ...                  100.0               NaN  1550.000000
# 121118        NaN  ...                    NaN       2346.938776          NaN
#
#         floor  rooms  expenses  \
# 18        NaN    NaN       NaN
# 237       NaN    NaN       NaN
# 239       NaN    NaN       NaN
# 387       NaN    NaN       NaN
# 410       NaN    NaN       NaN
# ...       ...    ...       ...
# 120949    NaN    NaN       NaN
# 120951    NaN    NaN       NaN
# 121089    NaN    NaN       NaN
# 121104    NaN    NaN       NaN
# 121118    NaN    NaN    2100.0
#
#                                             properati_url  \
# 18      http://www.properati.com.ar/15bq1_venta_casa_t...
# 237     http://www.properati.com.ar/15dmg_venta_casa_s...
# 239     http://www.properati.com.ar/15dmj_venta_casa_t...
# 387     http://www.properati.com.ar/15edj_venta_casa_b...
# 410     http://www.properati.com.ar/15eh1_venta_casa_t...
# ...                                                   ...
# 120949  http://www.properati.com.ar/1cim0_venta_casa_t...
# 120951  http://www.properati.com.ar/1cim2_venta_casa_t...
# 121089  http://www.properati.com.ar/1cj2t_venta_casa_t...
# 121104  http://www.properati.com.ar/1cj3h_venta_ph_tig...
# 121118  http://www.properati.com.ar/1cj41_venta_depart...
#
#                                               description  \
# 18      Casa sobre lote al golf en barrio San Isidro L...
# 237     CASA EN VENTA EN SAN ISIDRO LABRADOR. LOTE INT...
# 239     CASA EN VENTA EN SAN ISIDRO LABRADOR. LOTE INT...
# 387     Hermosa casa en barrio privado San Isidro Labr...
# 410     JPL. Santa Teresa 4 dormitorios. La casa se en...
# ...                                                   ...
# 120949                  Excelente calidad, casa de dos...
# 120951                  Excelente Casa de Calidad en v...
# 121089  Muy linda casa en el barrio San Rafael, sobre ...
# 121104  Tigre, Chacabuco 200PH tipo casa en centro de ...
# 121118  TIGRE, MONTEVIDEO 1300 - Excelente departament...
#
#                                                     title  \
# 18      Casa en venta en barrio San Isidro Labrador, T...
# 237                  CASA EN VENTA EN SAN ISIDRO LABRADOR
# 239                  CASA EN VENTA EN SAN ISIDRO LABRADOR
# 387                             EXCELENTE CASA CON AMARRA
# 410                      JPL. Santa Teresa 4 dormitorios.
# ...                                                   ...
# 120949                              Casa - Santa Catalina
# 120951                         Casa - San Isidro Labrador
# 121089                                  Casa - San Rafael
# 121104                                         PH - Tigre
# 121118              Venta departamento 1 ambiente - Tigre
#
#                                           image_thumbnail
# 18      https://thumbs4.properati.com/6/4N9cpurqmDMKEX...
# 237     https://thumbs4.properati.com/1/aWf3FMfaR49RGu...
# 239     https://thumbs4.properati.com/2/nfWtaEhDN_7rgp...
# 387     https://thumbs4.properati.com/2/jLrQa8w5cZwplG...
# 410     https://thumbs4.properati.com/6/xDhfoi_IE0gqR9...
# ...                                                   ...
# 120949  https://thumbs4.properati.com/4/ApR9Pe_6mD61mr...
# 120951  https://thumbs4.properati.com/6/Bd4ns-uTrmHBqx...
# 121089  https://thumbs4.properati.com/5/zPkAPfIQUloyzr...
# 121104  https://thumbs4.properati.com/4/fAJmZWV7DfXJcR...
# 121118  https://thumbs4.properati.com/2/2qYSEo3yI9J0_-...
#
# [3324 rows x 26 columns]

# %%
data.place_with_parent_names.value_counts()
# Out:
# |Argentina|Santa Fe|Rosario|                                                     8504
# |Argentina|Córdoba|Córdoba|                                                      6606
# |Argentina|Buenos Aires Costa Atlántica|Mar del Plata|                           6534
# |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nordelta|                              3315
# |Argentina|Capital Federal|Belgrano|                                             2992
#                                                                                  ...
# |Argentina|Bs.As. G.B.A. Zona Sur|Berazategui|El Pato Country Club|                 1
# |Argentina|Buenos Aires Interior|Ramallo|Ramallo|                                   1
# |Argentina|Tucumán|Villa Belgrano|                                                  1
# |Argentina|Córdoba|Laguna Larga|                                                    1
# |Argentina|Bs.As. G.B.A. Zona Sur|Esteban Echeverría|Country Golf El Sosiego|       1
# Name: place_with_parent_names, Length: 1164, dtype: int64

# %%
data.country_name.value_counts()
# Out:
# Argentina    121220
# Name: country_name, dtype: int64

# %%
data.place_name.value_counts()
# Out:
# Córdoba                       9254
# Rosario                       8504
# Mar del Plata                 6534
# Tigre                         3324
# Nordelta                      3315
#                               ...
# Perú                             1
# Agua Blanca                      1
# Gobernador Benegas               1
# Carmen de Patagones              1
# La Escondida de Manzanares       1
# Name: place_name, Length: 1060, dtype: int64

# %%
data.state_name.value_counts()
# Out:
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Río Negro                         808
# Neuquén                           733
# Mendoza                           681
# Tucumán                           674
# Corrientes                        583
# Misiones                          464
# Entre Ríos                        369
# Salta                             278
# Chubut                            259
# San Luis                          252
# La Pampa                          157
# Formosa                            65
# Chaco                              57
# San Juan                           40
# Tierra Del Fuego                   31
# Catamarca                          27
# Jujuy                              26
# Santa Cruz                         20
# Santiago Del Estero                 4
# La Rioja                            4
# Name: state_name, dtype: int64

# %%
mask = data['place_name'] == 'Palermo Hollywood'
mask2 = data['geonames_id'].notnull()
data.loc[mask & mask2, ['place_name','state_name','geonames_id']]

#mask = data['geonames_id'].isnull()
#data.loc[mask,['place_name','state_name','geonames_id']]
# Out:
# Empty DataFrame
# Columns: [place_name, state_name, geonames_id]
# Index: []

# %%
#Verificamos lat-lon , lat y lon
data.iloc[:,3:11]
mask = data['lat'].isnull()
mask2 = data['lon'].isnull()
mask3 = data['lat-lon'].isnull()

data.loc[mask & mask2 & mask3]
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 13              13      sell     apartment     Palermo Soho
# 14              14      sell     apartment     Palermo Soho
# 23              23      sell     apartment            Pilar
# 42              42      sell         house            Pilar
# 49              49      sell         house          Escobar
# ...            ...       ...           ...              ...
# 121214      121214      sell         store       San Isidro
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 13       |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 14       |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 23       |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Pilar|    Argentina
# 42             |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 49           |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|    Argentina
# ...                                                   ...          ...
# 121214    |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|    Argentina
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id lat-lon  lat  ...  \
# 13                   Capital Federal    3430234.0     NaN  NaN  ...
# 14                   Capital Federal    3430234.0     NaN  NaN  ...
# 23          Bs.As. G.B.A. Zona Norte          NaN     NaN  NaN  ...
# 42          Bs.As. G.B.A. Zona Norte    3429979.0     NaN  NaN  ...
# 49          Bs.As. G.B.A. Zona Norte    3434130.0     NaN  NaN  ...
# ...                              ...          ...     ...  ...  ...
# 121214      Bs.As. G.B.A. Zona Norte    3428983.0     NaN  NaN  ...
# 121215               Capital Federal    3436077.0     NaN  NaN  ...
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0     NaN  NaN  ...
# 121218  Buenos Aires Costa Atlántica          NaN     NaN  NaN  ...
# 121219               Capital Federal    3433955.0     NaN  NaN  ...
#
#         surface_covered_in_m2  price_usd_per_m2 price_per_m2  floor  rooms  \
# 13                       30.0       2234.000000  3723.333333    NaN    1.0
# 14                       31.0       3521.428571  4770.967742    NaN    1.0
# 23                       42.0       1708.333333  1952.380952    NaN    2.0
# 42                       47.0       1574.468085  1574.468085    NaN    NaN
# 49                      250.0        980.000000   980.000000    NaN    NaN
# ...                       ...               ...          ...    ...    ...
# 121214                  123.0               NaN          NaN    NaN    NaN
# 121215                   93.0       7699.115044  9354.838710    NaN    NaN
# 121216                  360.0       1383.333333  1383.333333    NaN    NaN
# 121218                   48.0       1997.916667  1997.916667    NaN    NaN
# 121219                   77.0       1675.324675  1675.324675    NaN    NaN
#
#         expenses                                      properati_url  \
# 13           NaN  http://www.properati.com.ar/15bp9_venta_depart...
# 14           NaN  http://www.properati.com.ar/15bpa_venta_depart...
# 23           NaN  http://www.properati.com.ar/15bqt_venta_depart...
# 42           NaN  http://www.properati.com.ar/15btc_venta_casa_p...
# 49           NaN  http://www.properati.com.ar/15bu6_venta_casa_e...
# ...          ...                                                ...
# 121214       NaN  http://www.properati.com.ar/1cja1_venta_local_...
# 121215   10000.0  http://www.properati.com.ar/1cja2_venta_depart...
# 121216       NaN  http://www.properati.com.ar/1cja6_venta_casa_b...
# 121218       NaN  http://www.properati.com.ar/1cja8_venta_depart...
# 121219    3500.0  http://www.properati.com.ar/1cjaa_venta_depart...
#
#                                               description  \
# 13       Torre I Mondrian. 3 ambientes con terraza y d...
# 14      Torre II Dalí. Ambiente unico divisible.Vitrau...
# 23      Hermoso departamento, ubicado en la calle Almi...
# 42      Ubicado en planta baja, posee patio y un area ...
# 49      JPL. Casa en el barrio San Sebastian con bajad...
# ...                                                   ...
# 121214   ***VENTA CON RENTA***Local en EDIFICIO lomas ...
# 121215  TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...
# 121216  Excelente e impecable casa en Venta en Las Lom...
# 121218  2 Amb al contrafrente,  luminoso. El departame...
# 121219  Departamento de 77 m2 apto profesional. Edific...
#
#                                                     title  \
# 13                                        Vitraux Palermo
# 14                                        Vitraux Palermo
# 23      Excelente departamento, Impecable!!! APTO CRED...
# 42      Duplex en Villa Morra  , muy buena ubicacion ,...
# 49                             JPL. Casa en San Sebastian
# ...                                                   ...
# 121214                                 Local - San Isidro
# 121215         Torre Forum Alcorta- Impecable 3 ambientes
# 121216  Ruca Inmuebles | Venta | Lomas de San Isidro |...
# 121218  2 amb. C/ dep. de servicio al contrafrente| Re...
# 121219         Departamento apto profesional en el Centro
#
#                                           image_thumbnail
# 13      https://thumbs4.properati.com/2/ZTUjkRzTz6YvcU...
# 14      https://thumbs4.properati.com/8/Uay2dC732CNlRw...
# 23      https://thumbs4.properati.com/8/BHyv2zmce3bVoU...
# 42      https://thumbs4.properati.com/7/kF2WVg6KNMRHSO...
# 49      https://thumbs4.properati.com/8/02qopPWAD_DIne...
# ...                                                   ...
# 121214  https://thumbs4.properati.com/7/R-j0JiSePtAriH...
# 121215  https://thumbs4.properati.com/1/bjms0KnaAnlNoQ...
# 121216  https://thumbs4.properati.com/2/PCc3WuQDjpNZc4...
# 121218  https://thumbs4.properati.com/8/Q12PTvU6BQJ0ib...
# 121219  https://thumbs4.properati.com/8/mNEsnQWqB7joBF...
#
# [51550 rows x 26 columns]

# %%
#data.iloc[:, 11:15]
#data.currency.value_counts()
mask = data['currency'] == 'ARS'
data.columns
data.loc[mask,['price','currency','price_aprox_local_currency','price_aprox_usd']]
data['pesos'] = data['price_aprox_local_currency'] / data['price_aprox_usd']
data['pesos'].value_counts()

mask1 = data['price'].isnull()
mask2 = data['price_aprox_local_currency'].isnull()
mask3 = data['price_aprox_usd'].isnull()
data.loc[mask1 & mask2 & mask3,['price','currency','price_aprox_local_currency','price_aprox_usd']]
# Out:
#         price currency  price_aprox_local_currency  price_aprox_usd
# 5         NaN      NaN                         NaN              NaN
# 20        NaN      NaN                         NaN              NaN
# 41        NaN      NaN                         NaN              NaN
# 62        NaN      NaN                         NaN              NaN
# 67        NaN      NaN                         NaN              NaN
# ...       ...      ...                         ...              ...
# 121210    NaN      NaN                         NaN              NaN
# 121211    NaN      NaN                         NaN              NaN
# 121212    NaN      NaN                         NaN              NaN
# 121213    NaN      NaN                         NaN              NaN
# 121214    NaN      NaN                         NaN              NaN
#
# [20410 rows x 4 columns]

# %%
data.columns
mask1 = data['price'].isnull()
mask2 = data['price_usd_per_m2'].isnull()
mask3 = data['price_per_m2'].isnull()
data.loc[mask1 & mask2 & mask3,['price','price_usd_per_m2','price_per_m2']]
# Out:
#         price  price_usd_per_m2  price_per_m2
# 5         NaN               NaN           NaN
# 20        NaN               NaN           NaN
# 41        NaN               NaN           NaN
# 62        NaN               NaN           NaN
# 67        NaN               NaN           NaN
# ...       ...               ...           ...
# 121210    NaN               NaN           NaN
# 121211    NaN               NaN           NaN
# 121212    NaN               NaN           NaN
# 121213    NaN               NaN           NaN
# 121214    NaN               NaN           NaN
#
# [20410 rows x 3 columns]

# %%
data.columns
mask1 = data['surface_total_in_m2'].isnull()
mask2 = data['surface_covered_in_m2'].isnull()
data.loc[mask1 & mask2,['price','price_usd_per_m2','price_per_m2']]
# Out:
#            price  price_usd_per_m2  price_per_m2
# 1       150000.0               NaN           NaN
# 3        95000.0               NaN           NaN
# 9       460000.0               NaN           NaN
# 11      150000.0               NaN           NaN
# 65       50000.0               NaN           NaN
# ...          ...               ...           ...
# 121086       NaN               NaN           NaN
# 121101  370000.0               NaN           NaN
# 121133  110000.0               NaN           NaN
# 121134  250000.0               NaN           NaN
# 121144  350000.0               NaN           NaN
#
# [12369 rows x 3 columns]

# %%
data.columns
maskCasa = data['property_type'] == 'apartment'
maskFloor = data['floor'] > 0
data.loc[maskCasa & maskFloor,['property_type','floor']]



data[(data['floor'] > 1) & (data['property_type'] == 'house')].description
#sns.barplot(data=data, x="property_type", y="floor")

data[['description','floor']]
# Out:
#                                               description  floor
# 0       2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...    NaN
# 1       Venta de departamento en décimo piso al frente...    NaN
# 2       2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...    NaN
# 3       PH 3 ambientes con patio. Hay 3 deptos en lote...    NaN
# 4       DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...    NaN
# ...                                                   ...    ...
# 121215  TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...    NaN
# 121216  Excelente e impecable casa en Venta en Las Lom...    NaN
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...    NaN
# 121218  2 Amb al contrafrente,  luminoso. El departame...    NaN
# 121219  Departamento de 77 m2 apto profesional. Edific...    NaN
#
# [121220 rows x 2 columns]

# %%
data.rooms.value_counts()
# Out:
# 3.0     12567
# 2.0     12433
# 4.0      7937
# 1.0      7377
# 5.0      3782
# 6.0      1403
# 7.0       770
# 8.0       409
# 10.0      226
# 9.0       184
# 11.0       72
# 12.0       65
# 13.0       33
# 14.0       27
# 15.0       26
# 17.0       16
# 16.0       11
# 20.0       11
# 22.0        8
# 18.0        6
# 21.0        5
# 30.0        4
# 25.0        4
# 19.0        4
# 32.0        3
# 23.0        2
# 24.0        1
# 27.0        1
# 29.0        1
# 31.0        1
# 28.0        1
# Name: rooms, dtype: int64

# %%
display (data.pivot_table(["country_name"],"rooms","property_type", aggfunc="count"))
# Out:
#               country_name
# property_type           PH apartment   house store
# rooms
# 1.0                  118.0    6940.0   264.0  55.0
# 2.0                  744.0   10664.0  1008.0  17.0
# 3.0                 1301.0    7946.0  3307.0  13.0
# 4.0                  705.0    3867.0  3361.0   4.0
# 5.0                  263.0    1162.0  2353.0   4.0
# 6.0                   69.0     330.0  1002.0   2.0
# 7.0                   24.0     174.0   566.0   6.0
# 8.0                   10.0      86.0   312.0   1.0
# 9.0                    5.0      34.0   145.0   NaN
# 10.0                   4.0      22.0   197.0   3.0
# 11.0                   1.0       9.0    62.0   NaN
# 12.0                   1.0      12.0    52.0   NaN
# 13.0                   1.0       3.0    29.0   NaN
# 14.0                   NaN       5.0    22.0   NaN
# 15.0                   NaN       2.0    24.0   NaN
# 16.0                   NaN       NaN    11.0   NaN
# 17.0                   NaN       3.0    13.0   NaN
# 18.0                   NaN       1.0     5.0   NaN
# 19.0                   NaN       NaN     4.0   NaN
# 20.0                   1.0       2.0     8.0   NaN
# 21.0                   NaN       1.0     4.0   NaN
# 22.0                   NaN       2.0     6.0   NaN
# 23.0                   NaN       NaN     2.0   NaN
# 24.0                   NaN       NaN     1.0   NaN
# 25.0                   NaN       1.0     3.0   NaN
# 27.0                   NaN       NaN     1.0   NaN
# 28.0                   NaN       NaN     1.0   NaN
# 29.0                   NaN       NaN     1.0   NaN
# 30.0                   NaN       NaN     4.0   NaN
# 31.0                   NaN       NaN     1.0   NaN
# 32.0                   NaN       2.0     1.0   NaN

# %%
display (data.pivot_table(["country_name"],"floor","property_type", aggfunc="count"))
# Out:
#               country_name
# property_type           PH apartment  house store
# floor
# 1.0                  154.0    1517.0  385.0  24.0
# 2.0                  146.0    1096.0  290.0  10.0
# 3.0                   63.0     833.0   18.0   NaN
# 4.0                   31.0     625.0    1.0   1.0
# 5.0                   38.0     444.0    2.0   NaN
# ...                    ...       ...    ...   ...
# 1609.0                 NaN       4.0    NaN   NaN
# 2103.0                 NaN       1.0    NaN   NaN
# 2177.0                 NaN       NaN    1.0   NaN
# 2509.0                 NaN       1.0    NaN   NaN
# 3150.0                 NaN       NaN    1.0   NaN
#
# [182 rows x 4 columns]

# %%
data[data['floor'] == 3150]
# Out:
#        Unnamed: 0 operation property_type place_name  \
# 39394       39394      sell         house     Nogoyá
#
#              place_with_parent_names country_name  state_name  geonames_id  \
# 39394  |Argentina|Entre Ríos|Nogoyá|    Argentina  Entre Ríos    3430412.0
#
#                        lat-lon       lat  ...  price_usd_per_m2  price_per_m2  \
# 39394  -32.3977301,-59.7901354 -32.39773  ...               NaN           NaN
#
#         floor  rooms  expenses  \
# 39394  3150.0    5.0       NaN
#
#                                            properati_url  \
# 39394  http://www.properati.com.ar/18o8m_venta_casa_n...
#
#                                              description          title  \
# 39394  Amplia casa con local en pleno centro a una cu...  CASA EN VENTA
#
#                                          image_thumbnail  pesos
# 39394  https://thumbs4.properati.com/5/03IWlqTkvN9OYg...    NaN
#
# [1 rows x 27 columns]

# %%
data.columns
mask1 = data['expenses'].isnull()
mask2 = data['property_type'] == 'apartment'
data.loc[mask1 & mask2]
# Out:
#         Unnamed: 0 operation property_type     place_name  \
# 1                1      sell     apartment       La Plata
# 2                2      sell     apartment      Mataderos
# 4                4      sell     apartment         Centro
# 7                7      sell     apartment       Belgrano
# 8                8      sell     apartment       Belgrano
# ...            ...       ...           ...            ...
# 121205      121205      sell     apartment        Córdoba
# 121206      121206      sell     apartment        Córdoba
# 121211      121211      sell     apartment       Acassuso
# 121217      121217      sell     apartment  Villa Urquiza
# 121218      121218      sell     apartment    Plaza Colón
#
#                                   place_with_parent_names country_name  \
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 7                    |Argentina|Capital Federal|Belgrano|    Argentina
# 8                    |Argentina|Capital Federal|Belgrano|    Argentina
# ...                                                   ...          ...
# 121205                                |Argentina|Córdoba|    Argentina
# 121206                                |Argentina|Córdoba|    Argentina
# 121211  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                           state_name  geonames_id  \
# 1             Bs.As. G.B.A. Zona Sur    3432039.0
# 2                    Capital Federal    3430787.0
# 4       Buenos Aires Costa Atlántica    3435548.0
# 7                    Capital Federal    3436077.0
# 8                    Capital Federal    3436077.0
# ...                              ...          ...
# 121205                       Córdoba    3860255.0
# 121206                       Córdoba    3860255.0
# 121211      Bs.As. G.B.A. Zona Norte    3436508.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
#
#                               lat-lon        lat  ...  price_usd_per_m2  \
# 1             -34.9038831,-57.9643295 -34.903883  ...               NaN
# 2             -34.6522615,-58.5229825 -34.652262  ...       1309.090909
# 4             -38.0026256,-57.5494468 -38.002626  ...       1828.571429
# 7              -34.5598729,-58.443362 -34.559873  ...       3066.666667
# 8              -34.5598729,-58.443362 -34.559873  ...       3000.000000
# ...                               ...        ...  ...               ...
# 121205                            NaN        NaN  ...       1690.362000
# 121206                            NaN        NaN  ...       1690.362000
# 121211                            NaN        NaN  ...               NaN
# 121217  -34.5706388726,-58.4755963355 -34.570639  ...       2858.695652
# 121218                            NaN        NaN  ...       1997.916667
#
#         price_per_m2 floor  rooms  expenses  \
# 1                NaN   NaN    NaN       NaN
# 2        1309.090909   NaN    NaN       NaN
# 4        1828.571429   NaN    NaN       NaN
# 7        3450.000000   NaN    NaN       NaN
# 8        3250.000000   NaN    NaN       NaN
# ...              ...   ...    ...       ...
# 121205           NaN   NaN    NaN       NaN
# 121206           NaN   NaN    NaN       NaN
# 121211           NaN   NaN    NaN       NaN
# 121217   3371.794872   NaN    NaN       NaN
# 121218   1997.916667   NaN    NaN       NaN
#
#                                             properati_url  \
# 1       http://www.properati.com.ar/15bob_venta_depart...
# 2       http://www.properati.com.ar/15bod_venta_depart...
# 4       http://www.properati.com.ar/15bok_venta_depart...
# 7       http://www.properati.com.ar/15bot_venta_depart...
# 8       http://www.properati.com.ar/15bou_venta_depart...
# ...                                                   ...
# 121205  http://www.properati.com.ar/1cj74_venta_depart...
# 121206  http://www.properati.com.ar/1cj75_venta_depart...
# 121211  http://www.properati.com.ar/1cj9y_venta_depart...
# 121217  http://www.properati.com.ar/1cja7_venta_depart...
# 121218  http://www.properati.com.ar/1cja8_venta_depart...
#
#                                               description  \
# 1       Venta de departamento en décimo piso al frente...
# 2       2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 4       DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 7       EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8       EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
# ...                                                   ...
# 121205  UBICACIÓNEstratégicamente ubicado en calle Obi...
# 121206  UBICACIÓNEstratégicamente ubicado en calle Obi...
# 121211  Excelente departamento de categoría con vistas...
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218  2 Amb al contrafrente,  luminoso. El departame...
#
#                                                     title  \
# 1       VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2                2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 4       DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
# 7       JOSE HERNANDEZ 1400 MONOAMBIENTE  ESTRENAR CAT...
# 8       JOSE HERNANDEZ   1400 DOS AMBIENTES ESTRENAR ,...
# ...                                                   ...
# 121205                       Departamento - Nueva Cordoba
# 121206                       Departamento - Nueva Cordoba
# 121211                            Departamento - Acassuso
# 121217  VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218  2 amb. C/ dep. de servicio al contrafrente| Re...
#
#                                           image_thumbnail    pesos
# 1       https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  17.6445
# 2       https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  17.6445
# 4       https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  17.6445
# 7       https://thumbs4.properati.com/1/IHxARynlr8sPEW...  17.6445
# 8       https://thumbs4.properati.com/2/J3zOjgaFHrkvnv...  17.6445
# ...                                                   ...      ...
# 121205                                                NaN  17.6445
# 121206                                                NaN  17.6445
# 121211  https://thumbs4.properati.com/0/pvevdNsjE5Kf4r...      NaN
# 121217  https://thumbs4.properati.com/9/YAe_-2gRVykADP...  17.6445
# 121218  https://thumbs4.properati.com/8/Q12PTvU6BQJ0ib...  17.6445
#
# [59861 rows x 27 columns]

# %%
import numpy as np
data["tipo_de_cambio"]=round(data.price_aprox_local_currency/data.price_aprox_usd,2)
print(f'Desvío tipo de cambio= ', data.tipo_de_cambio.std())
data.tipo_de_cambio.value_counts()
print(f'Tipo de cambio nulos: ', data.tipo_de_cambio.isnull().sum())

#Conclusión: el tipo de cambio es siempre el mismo si lo redondeamos, con lo cual podríamos dejar el precio (la columna price) en dólares,/
#haciendo las conversiones necesarias para los precios que no están en dólares originalmente. Esto sacaría las columnas 'currency',/
# price_aprox_local_currency' y 'price_aprox_usd'. Obs: renombrar price = price_usd.
# Out:
# Desvío tipo de cambio=  7.105462599891974e-15
# Tipo de cambio nulos:  20411

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'pesos', 'tipo_de_cambio'],
#       dtype='object')

# %%
datitos=data
datitos.drop("tipo_de_cambio",axis=1,inplace=True)
datitos.head()
# Out:
#    Unnamed: 0 operation property_type place_name  \
# 0           0      sell            PH  Mataderos
# 1           1      sell     apartment   La Plata
# 2           2      sell     apartment  Mataderos
# 3           3      sell            PH    Liniers
# 4           4      sell     apartment     Centro
#
#                              place_with_parent_names country_name  \
# 0              |Argentina|Capital Federal|Mataderos|    Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2              |Argentina|Capital Federal|Mataderos|    Argentina
# 3                |Argentina|Capital Federal|Liniers|    Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                      state_name  geonames_id                  lat-lon  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#          lat  ...  price_usd_per_m2  price_per_m2 floor  rooms  expenses  \
# 0 -34.661824  ...       1127.272727   1550.000000   NaN    NaN       NaN
# 1 -34.903883  ...               NaN           NaN   NaN    NaN       NaN
# 2 -34.652262  ...       1309.090909   1309.090909   NaN    NaN       NaN
# 3 -34.647797  ...               NaN           NaN   NaN    NaN       NaN
# 4 -38.002626  ...       1828.571429   1828.571429   NaN    NaN       NaN
#
#                                        properati_url  \
# 0  http://www.properati.com.ar/15bo8_venta_ph_mat...
# 1  http://www.properati.com.ar/15bob_venta_depart...
# 2  http://www.properati.com.ar/15bod_venta_depart...
# 3  http://www.properati.com.ar/15boh_venta_ph_lin...
# 4  http://www.properati.com.ar/15bok_venta_depart...
#
#                                          description  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                                title  \
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
#                                      image_thumbnail    pesos
# 0  https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  17.6445
# 1  https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  17.6445
# 2  https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  17.6445
# 3  https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  17.6445
# 4  https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  17.6445
#
# [5 rows x 27 columns]

# %%
datitos["país_extraído"]=datitos["place_with_parent_names"].apply(lambda x: x.split("|")[1])
datitos["país_extraído_sin_espacios"]=datitos["país_extraído"].apply(lambda x: x.strip())
datitos["país_extraído_sin_espacios"].value_counts()
# Out:
# Argentina    121220
# Name: país_extraído_sin_espacios, dtype: int64

# %%
data.country_name.value_counts()
#Conclusión: el país el mismo en place_with_parent_names que en country_name.
# Out:
# Argentina    121220
# Name: country_name, dtype: int64

# %%
datitos["provincia_extraída"]=datitos["place_with_parent_names"].apply(lambda x: x.split("|")[2])
datitos["provincia_extraída_sin_espacios"]=datitos["provincia_extraída"].apply(lambda x: x.strip())
datitos["provincia_extraída_sin_espacios"].value_counts()
# Out:
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Río Negro                         808
# Neuquén                           733
# Mendoza                           681
# Tucumán                           674
# Corrientes                        583
# Misiones                          464
# Entre Ríos                        369
# Salta                             278
# Chubut                            259
# San Luis                          252
# La Pampa                          157
# Formosa                            65
# Chaco                              57
# San Juan                           40
# Tierra Del Fuego                   31
# Catamarca                          27
# Jujuy                              26
# Santa Cruz                         20
# Santiago Del Estero                 4
# La Rioja                            4
# Name: provincia_extraída_sin_espacios, dtype: int64

# %%
datitos["provincia_original_sin_espacios"]=datitos["state_name"].apply(lambda x: x.strip())
mascara_provincia=datitos["provincia_extraída_sin_espacios"]==datitos["provincia_original_sin_espacios"]
datitos.loc[mascara_provincia].shape, datitos.shape
# Out:
# ((121220, 32), (121220, 32))

# %%
datitos["provincia_extraída_sin_espacios"].value_counts()==datitos["provincia_original_sin_espacios"].value_counts()
#Conclusión: state_name tb coincice en parent_place_name.
# Out:
# Capital Federal                 True
# Bs.As. G.B.A. Zona Norte        True
# Bs.As. G.B.A. Zona Sur          True
# Córdoba                         True
# Santa Fe                        True
# Buenos Aires Costa Atlántica    True
# Bs.As. G.B.A. Zona Oeste        True
# Buenos Aires Interior           True
# Río Negro                       True
# Neuquén                         True
# Mendoza                         True
# Tucumán                         True
# Corrientes                      True
# Misiones                        True
# Entre Ríos                      True
# Salta                           True
# Chubut                          True
# San Luis                        True
# La Pampa                        True
# Formosa                         True
# Chaco                           True
# San Juan                        True
# Tierra Del Fuego                True
# Catamarca                       True
# Jujuy                           True
# Santa Cruz                      True
# Santiago Del Estero             True
# La Rioja                        True
# dtype: bool

# %%
datitos["localidad_extraída"]=datitos["place_with_parent_names"].apply(lambda x: x.split("|")[-2])
datitos["localidad_extraída_sin_espacios"]=datitos["localidad_extraída"].apply(lambda x: x.strip())
print(f'shape: ', datitos["localidad_extraída_sin_espacios"].value_counts().shape)
datitos["localidad_extraída_sin_espacios"].value_counts()
# Out:
# shape:  (1061,)
# Córdoba                       9254
# Rosario                       8504
# Mar del Plata                 6534
# Tigre                         3324
# Nordelta                      3315
#                               ...
# Arroyo Ceibal                    1
# Ramallo                          1
# Trenel                           1
# Mar de Cobo                      1
# La Escondida de Manzanares       1
# Name: localidad_extraída_sin_espacios, Length: 1061, dtype: int64

# %%
datitos["place_name"]=datitos["place_name"].astype(str)
datitos["localidad_original_sin_espacios"]=datitos["place_name"].apply(lambda x: x.strip())
print(f'shape:', datitos["localidad_original_sin_espacios"].value_counts().shape)
mascara_localidad=datitos["localidad_extraída_sin_espacios"]==datitos["localidad_original_sin_espacios"]
datitos[mascara_localidad]
# Out:
# shape: (1061,)
#         Unnamed: 0 operation property_type       place_name  \
# 0                0      sell            PH        Mataderos
# 1                1      sell     apartment         La Plata
# 2                2      sell     apartment        Mataderos
# 3                3      sell            PH          Liniers
# 4                4      sell     apartment           Centro
# ...            ...       ...           ...              ...
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121217      121217      sell     apartment    Villa Urquiza
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 3                     |Argentina|Capital Federal|Liniers|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...                                                   ...          ...
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 0                    Capital Federal    3430787.0
# 1             Bs.As. G.B.A. Zona Sur    3432039.0
# 2                    Capital Federal    3430787.0
# 3                    Capital Federal    3431333.0
# 4       Buenos Aires Costa Atlántica    3435548.0
# ...                              ...          ...
# 121215               Capital Federal    3436077.0
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
# 121219               Capital Federal    3433955.0
#
#                               lat-lon        lat  ...  \
# 0             -34.6618237,-58.5088387 -34.661824  ...
# 1             -34.9038831,-57.9643295 -34.903883  ...
# 2             -34.6522615,-58.5229825 -34.652262  ...
# 3             -34.6477969,-58.5164244 -34.647797  ...
# 4             -38.0026256,-57.5494468 -38.002626  ...
# ...                               ...        ...  ...
# 121215                            NaN        NaN  ...
# 121216                            NaN        NaN  ...
# 121217  -34.5706388726,-58.4755963355 -34.570639  ...
# 121218                            NaN        NaN  ...
# 121219                            NaN        NaN  ...
#
#                                           image_thumbnail    pesos  \
# 0       https://thumbs4.properati.com/8/BluUYiHJLhgIIK...  17.6445
# 1       https://thumbs4.properati.com/7/ikpVBu2ztHA7jv...  17.6445
# 2       https://thumbs4.properati.com/5/SXKr34F_IwG3W_...  17.6445
# 3       https://thumbs4.properati.com/3/DgIfX-85Mog5SP...  17.6445
# 4       https://thumbs4.properati.com/5/xrRqlNcSI_vs-f...  17.6445
# ...                                                   ...      ...
# 121215  https://thumbs4.properati.com/1/bjms0KnaAnlNoQ...  17.6445
# 121216  https://thumbs4.properati.com/2/PCc3WuQDjpNZc4...  17.6445
# 121217  https://thumbs4.properati.com/9/YAe_-2gRVykADP...  17.6445
# 121218  https://thumbs4.properati.com/8/Q12PTvU6BQJ0ib...  17.6445
# 121219  https://thumbs4.properati.com/8/mNEsnQWqB7joBF...  17.6445
#
#        país_extraído  país_extraído_sin_espacios  \
# 0          Argentina                   Argentina
# 1          Argentina                   Argentina
# 2          Argentina                   Argentina
# 3          Argentina                   Argentina
# 4          Argentina                   Argentina
# ...              ...                         ...
# 121215     Argentina                   Argentina
# 121216     Argentina                   Argentina
# 121217     Argentina                   Argentina
# 121218     Argentina                   Argentina
# 121219     Argentina                   Argentina
#
#                   provincia_extraída  provincia_extraída_sin_espacios  \
# 0                    Capital Federal                  Capital Federal
# 1             Bs.As. G.B.A. Zona Sur           Bs.As. G.B.A. Zona Sur
# 2                    Capital Federal                  Capital Federal
# 3                    Capital Federal                  Capital Federal
# 4       Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# ...                              ...                              ...
# 121215               Capital Federal                  Capital Federal
# 121216      Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 121217               Capital Federal                  Capital Federal
# 121218  Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# 121219               Capital Federal                  Capital Federal
#
#         provincia_original_sin_espacios  localidad_extraída  \
# 0                       Capital Federal           Mataderos
# 1                Bs.As. G.B.A. Zona Sur            La Plata
# 2                       Capital Federal           Mataderos
# 3                       Capital Federal             Liniers
# 4          Buenos Aires Costa Atlántica              Centro
# ...                                 ...                 ...
# 121215                  Capital Federal            Belgrano
# 121216         Bs.As. G.B.A. Zona Norte              Beccar
# 121217                  Capital Federal       Villa Urquiza
# 121218     Buenos Aires Costa Atlántica         Plaza Colón
# 121219                  Capital Federal     Capital Federal
#
#         localidad_extraída_sin_espacios  localidad_original_sin_espacios
# 0                             Mataderos                        Mataderos
# 1                              La Plata                         La Plata
# 2                             Mataderos                        Mataderos
# 3                               Liniers                          Liniers
# 4                                Centro                           Centro
# ...                                 ...                              ...
# 121215                         Belgrano                         Belgrano
# 121216                           Beccar                           Beccar
# 121217                    Villa Urquiza                    Villa Urquiza
# 121218                      Plaza Colón                      Plaza Colón
# 121219                  Capital Federal                  Capital Federal
#
# [121197 rows x 35 columns]

# %%
datitos["extraído"]=datitos["place_with_parent_names"].apply(lambda x: x.split("|")[-2])
datitos["extraído"]
# Out:
# 0               Mataderos
# 1                La Plata
# 2               Mataderos
# 3                 Liniers
# 4                  Centro
#                ...
# 121215           Belgrano
# 121216             Beccar
# 121217      Villa Urquiza
# 121218        Plaza Colón
# 121219    Capital Federal
# Name: extraído, Length: 121220, dtype: object

# %%
#Conclusión: la columna place_with_parent_name sobra.

# %%
#datitos.drop("lat_extraída_sin_espacios",axis=1,inplace=True)

# %%
datitos["lat-lon"]=datitos["lat-lon"].astype(str)
datitos["lat_extraída"]=datitos["lat-lon"].apply(lambda x: x.split(",")[0])
datitos["lat_extraída"]=datitos["lat_extraída"].astype(float).round(6)
datitos["lat"]=datitos["lat"].round(6)
datitos["dif_lat"]=datitos["lat_extraída"]-datitos["lat"]
datitos["dif_lat"].value_counts()
#Conclusión: la lat es la misma en "lat" y en "lat-lon"
# Out:
#  0.000000e+00    69480
#  1.000000e-06       74
#  1.000000e-06       65
# -1.000000e-06       32
# -1.000000e-06       13
#  1.000000e-06        6
# Name: dif_lat, dtype: int64

# %%
datitos["lat-lon"]=datitos["lat-lon"].astype(str)
datitos["lon_extraída"]=datitos["lat-lon"].apply(lambda x: x.split(",")[-1])
datitos["lon_extraída"]=datitos["lon_extraída"].astype(float).round(6)
datitos["lon"]=datitos["lon"].round(6)
datitos["dif_lon"]=datitos["lon_extraída"]-datitos["lon"]
datitos["dif_lon"].value_counts()
#Conclusión: la lon es la misma en "lon" y en "lat-lon"
# Out:
#  0.000000e+00    69278
#  1.000000e-06      230
# -1.000000e-06      103
#  1.000000e-06       37
#  1.000000e-06       18
# -1.000000e-06        4
# Name: dif_lon, dtype: int64

# %%
datitos["lat-lon"].value_counts()
# Out:
# nan                              51550
# -34.4026444,-58.6684776            312
# -34.40014,-58.64985                271
# -34.6428675967,-58.4376599743      259
# -34.425087,-58.5796585             224
#                                  ...
# -31.4135885,-64.2355628              1
# -35.008505,-58.066843                1
# -34.5374652,-58.6989631              1
# -34.5844661312,-58.4385506771        1
# -38.7155844,-62.2621107              1
# Name: lat-lon, Length: 47204, dtype: int64

# %%
datitos.tail()
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121217      121217      sell     apartment    Villa Urquiza
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 121215               Capital Federal    3436077.0
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
# 121219               Capital Federal    3433955.0
#
#                               lat-lon        lat  ...  \
# 121215                            nan        NaN  ...
# 121216                            nan        NaN  ...
# 121217  -34.5706388726,-58.4755963355 -34.570639  ...
# 121218                            nan        NaN  ...
# 121219                            nan        NaN  ...
#
#         provincia_extraída_sin_espacios  provincia_original_sin_espacios  \
# 121215                  Capital Federal                  Capital Federal
# 121216         Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 121217                  Capital Federal                  Capital Federal
# 121218     Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# 121219                  Capital Federal                  Capital Federal
#
#        localidad_extraída  localidad_extraída_sin_espacios  \
# 121215           Belgrano                         Belgrano
# 121216             Beccar                           Beccar
# 121217      Villa Urquiza                    Villa Urquiza
# 121218        Plaza Colón                      Plaza Colón
# 121219    Capital Federal                  Capital Federal
#
#         localidad_original_sin_espacios         extraído  lat_extraída  \
# 121215                         Belgrano         Belgrano           NaN
# 121216                           Beccar           Beccar           NaN
# 121217                    Villa Urquiza    Villa Urquiza    -34.570639
# 121218                      Plaza Colón      Plaza Colón           NaN
# 121219                  Capital Federal  Capital Federal           NaN
#
#         dif_lat  lon_extraída  dif_lon
# 121215      NaN           NaN      NaN
# 121216      NaN           NaN      NaN
# 121217      0.0    -58.475596      0.0
# 121218      NaN           NaN      NaN
# 121219      NaN           NaN      NaN
#
# [5 rows x 40 columns]

# %%
datitos_sin_outliers=datitos["geonames_id"]<3440787.0
datitos[datitos_sin_outliers]
sns.scatterplot(x = datitos[datitos_sin_outliers].lat, y = datitos[datitos_sin_outliers].geonames_id, data = datitos_sin_outliers)
# Out:
# <AxesSubplot:xlabel='lat', ylabel='geonames_id'>

# %%
datitos.geonames_id
# Out:
# 0         3430787.0
# 1         3432039.0
# 2         3430787.0
# 3         3431333.0
# 4         3435548.0
#             ...
# 121215    3436077.0
# 121216    3436080.0
# 121217    3433775.0
# 121218          NaN
# 121219    3433955.0
# Name: geonames_id, Length: 121220, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
# creo los axes
ax = plt.axes()
# dibujo en axes:
ax.scatter(data.lat, data.geonames_id<4, marker = 'o', color = "green")
# superpongo otro gráfico en axes:

# %%
sns.scatterplot(x = datitos[datitos_sin_outliers].price_aprox_usd, y = datitos[datitos_sin_outliers].geonames_id, data = datitos_sin_outliers)
# Out:
# <AxesSubplot:xlabel='price_aprox_usd', ylabel='geonames_id'>

# %%
datitos[datitos["geonames_id"].isnull()]["place_name"].value_counts()/datitos["geonames_id"].isnull().sum()
# Out:
# Nordelta                      0.177112
# Lomas de Zamora               0.066944
# Lanús                         0.051878
# Tigre                         0.051557
# San Miguel                    0.040177
#                                 ...
# The Boating Club              0.000053
# Materno                       0.000053
# Laguna de los Padres          0.000053
# Villa Argüello                0.000053
# La Escondida de Manzanares    0.000053
# Name: place_name, Length: 467, dtype: float64

# %%
datitos["geonames_id"].isnull().sum()
# Out:
# 18717

# %%
datitos[datitos["geonames_id"].isnull()]["lat"].isnull().sum()
# Out:
# 8185

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'pesos', 'país_extraído',
#        'país_extraído_sin_espacios', 'provincia_extraída',
#        'provincia_extraída_sin_espacios', 'provincia_original_sin_espacios',
#        'localidad_extraída', 'localidad_extraída_sin_espacios',
#        'localidad_original_sin_espacios', 'extraído', 'lat_extraída',
#        'dif_lat', 'lon_extraída', 'dif_lon'],
#       dtype='object')

# %%
sns.scatterplot(data=data,x="surface_total_in_m2",y="price_aprox_usd",hue="property_type")
# Out:
# <AxesSubplot:xlabel='surface_total_in_m2', ylabel='price_aprox_usd'>

# %%
sns.scatterplot(data=data[data.property_type=="apartment"],x="expenses",y="price_aprox_usd",hue="property_type")
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='price_aprox_usd'>

# %%
sns.countplot(data=data,x="floor")
# Out:
# <AxesSubplot:xlabel='floor', ylabel='count'>

# %%
data_pisos_raros=data.floor>50
data[data_pisos_raros].floor.value_counts()
# Out:
# 108.0     5
# 1609.0    4
# 403.0     4
# 104.0     4
# 702.0     3
#          ..
# 57.0      1
# 60.0      1
# 94.0      1
# 205.0     1
# 708.0     1
# Name: floor, Length: 134, dtype: int64

# %%
sns.countplot(data=data[data_pisos_raros],x="floor")
# Out:
# <AxesSubplot:xlabel='floor', ylabel='count'>

# %%
data[data_pisos_raros].property_type.value_counts()
# Out:
# apartment    150
# house         34
# store          1
# Name: property_type, dtype: int64

# %%
import re

# %%
pattern_piso="piso"
pattern_piso_regex=re.compile(pattern_piso)
pattern_piso_regex.search("diez pisos")
# Out:
# <re.Match object; span=(5, 9), match='piso'>

# %%
data_con_piso=data.floor.notnull()
data_sin_piso=(data.floor.isnull())&(data.property_type=="apartment")
data[data_sin_piso].description
# Out:
# 1         Venta de departamento en décimo piso al frente...
# 2         2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 4         DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
# 7         EXCELENTE MONOAMBIENTE A ESTRENAR AMPLIO SUPER...
# 8         EXCELENTE DOS AMBIENTES  ESTRENAR AMPLIO SUPER...
#                                 ...
# 121211    Excelente departamento de categoría con vistas...
# 121215    TORRE FORUM ALCORTA - MÁXIMA CATEGORÍA.Impecab...
# 121217    VENTA DEPARTAMENTO AMBIENTE DIVISIBLE A ESTREN...
# 121218    2 Amb al contrafrente,  luminoso. El departame...
# 121219    Departamento de 77 m2 apto profesional. Edific...
# Name: description, Length: 64544, dtype: object

# %%
pattern_piso_match=data[data_sin_piso]["description"].apply(lambda x: x if x is np.NaN else pattern_piso_regex.search(x))
pattern_piso_match.isnull().sum()
# Out:
# 40585

# %%
pattern_piso_match.notnull().sum()
# Out:
# 23959

# %%
#Conclusión: Con tantos nulos, datos raros, etc, sufriendo podemos llegar a llenar 1/3 de los valores de Floor para departamentos. 
#Yo borraría la columna y me ahorraría la pena. Va a ser difícil saber si floor sirvió para algo si tuviste que imputar tanto.

# %%
pattern_precio="precio"
pattern_precio_regex=re.compile(pattern_precio)
pattern_piso_regex.search("precio")

# %%
data_sin_precio=data.price.isnull()
pattern_precio_match=data[data_sin_precio]["description"].apply(lambda x: x if x is np.NaN else pattern_precio_regex.search(x))
pattern_precio_match.isnull().sum(),pattern_precio_match.notnull().sum()
# Out:
# (18584, 1826)

# %%
pattern_dolar="U\$S"
pattern_dolar_regex=re.compile(pattern_dolar)
pattern_dolar_regex.search("10 U$S")
pattern_price="(?P<precio>(\d?\d?\.)?(\d?)\d\d\.\d\d\d)"
pattern_price_regex=re.compile(pattern_price)

# %%
data_sin_precio=data.price.isnull()
pattern_dolar_match=data[data_sin_precio]["description"].apply(lambda x: x if x is np.NaN else pattern_dolar_regex.search(x))
pattern_dolar_match.isnull().sum(),pattern_dolar_match.notnull().sum()
# Out:
# (19809, 601)

# %%
pattern_price_match=data[data_sin_precio]["description"].apply(lambda x: x if x is np.NaN else pattern_price_regex.search(x))
pattern_price_match.isnull().sum(),pattern_price_match.notnull().sum()
# Out:
# (18903, 1507)

# %%
pattern_dollar_price="(?P<dolares>U\$S)(.)(?P<precio>(\d?\d?\.)?(\d?)\d\d\.\d\d\d)"
pattern_dollar_price_regex=re.compile(pattern_dollar_price)
pattern_dollar_price_match=data[data_sin_precio]["description"].apply(lambda x: x if x is np.NaN else pattern_dollar_price_regex.search(x))
print(pattern_dollar_price_match.isnull().sum(),pattern_dollar_price_match.notnull().sum())
pattern_dollar_price_match_not_null=pattern_dollar_price_match.notnull()
# Out:
# 20136 274

# %%
data_sin_precio=data.price.isnull()
data_sin_precio_df=data[data_sin_precio]
type(data_sin_precio_df)
# Out:
# pandas.core.frame.DataFrame

# %%
pattern_peso_price="(?P<precio>(\d?\d?\.)?(\d?)\d\d\.\d\d\d)(.)(?P<pesos>pesos)"
pattern_peso_price_regex=re.compile(pattern_peso_price)
pattern_peso_price_match=data_sin_precio_df["description"].apply(lambda x: x if x is np.NaN else pattern_peso_price_regex.search(x))
print(pattern_peso_price_match.isnull().sum(),pattern_peso_price_match.notnull().sum())
pattern_peso_price_match_not_null=pattern_peso_price_match.notnull()
# Out:
# 20404 6

# %%
pattern_dollar_price_regex.search("U$S 20.000")
#data.loc[pattern_peso_price_match.notnull(), "precio_deducido"] = data_precio_match[data_precio_match_not_null].apply(lambda x: x.group("precio"))
#data_sin_precio_df.drop("preciotext_clean",axis=1)
data_sin_precio_df.loc[pattern_dollar_price_match_not_null, "precio_deducido"] = pattern_dollar_price_match[pattern_dollar_price_match_not_null].apply(lambda x: x.group("precio"))
data_sin_precio_df[pattern_dollar_price_match_not_null]
# Out:
# c:\Users\anacl\.conda\envs\dhdsblend2021\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# c:\Users\anacl\.conda\envs\dhdsblend2021\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#         Unnamed: 0 operation property_type     place_name  \
# 1665          1665      sell         house         Moreno
# 1666          1666      sell         house      Ituzaingó
# 1677          1677      sell         house      Ituzaingó
# 1690          1690      sell         house      Ituzaingó
# 1694          1694      sell     apartment      Ituzaingó
# ...            ...       ...           ...            ...
# 120767      120767      sell     apartment       Belgrano
# 120779      120779      sell            PH  Villa Urquiza
# 120783      120783      sell            PH  Villa Urquiza
# 120784      120784      sell            PH  Villa Urquiza
# 120886      120886      sell     apartment       Belgrano
#
#                                place_with_parent_names country_name  \
# 1665       |Argentina|Bs.As. G.B.A. Zona Oeste|Moreno|    Argentina
# 1666    |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|    Argentina
# 1677    |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|    Argentina
# 1690    |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|    Argentina
# 1694    |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|    Argentina
# ...                                                ...          ...
# 120767            |Argentina|Capital Federal|Belgrano|    Argentina
# 120779       |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 120783       |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 120784       |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 120886            |Argentina|Capital Federal|Belgrano|    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 1665    Bs.As. G.B.A. Zona Oeste    3430550.0                            nan
# 1666    Bs.As. G.B.A. Zona Oeste    3433359.0      -34.66341019,-58.67405701
# 1677    Bs.As. G.B.A. Zona Oeste    3433359.0      -34.66274261,-58.67403793
# 1690    Bs.As. G.B.A. Zona Oeste    3433359.0      -34.67317581,-58.67146683
# 1694    Bs.As. G.B.A. Zona Oeste    3433359.0      -34.66019821,-58.67018127
# ...                          ...          ...                            ...
# 120767           Capital Federal    3436077.0                            nan
# 120779           Capital Federal    3433775.0  -34.5646375217,-58.4853799092
# 120783           Capital Federal    3433775.0  -34.5646375217,-58.4853799092
# 120784           Capital Federal    3433775.0  -34.5646375217,-58.4853799092
# 120886           Capital Federal    3436077.0                            nan
#
#               lat  ...  provincia_original_sin_espacios  localidad_extraída  \
# 1665          NaN  ...         Bs.As. G.B.A. Zona Oeste              Moreno
# 1666   -34.663410  ...         Bs.As. G.B.A. Zona Oeste           Ituzaingó
# 1677   -34.662743  ...         Bs.As. G.B.A. Zona Oeste           Ituzaingó
# 1690   -34.673176  ...         Bs.As. G.B.A. Zona Oeste           Ituzaingó
# 1694   -34.660198  ...         Bs.As. G.B.A. Zona Oeste           Ituzaingó
# ...           ...  ...                              ...                 ...
# 120767        NaN  ...                  Capital Federal            Belgrano
# 120779 -34.564638  ...                  Capital Federal       Villa Urquiza
# 120783 -34.564638  ...                  Capital Federal       Villa Urquiza
# 120784 -34.564638  ...                  Capital Federal       Villa Urquiza
# 120886        NaN  ...                  Capital Federal            Belgrano
#
#        localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 1665                            Moreno                           Moreno
# 1666                         Ituzaingó                        Ituzaingó
# 1677                         Ituzaingó                        Ituzaingó
# 1690                         Ituzaingó                        Ituzaingó
# 1694                         Ituzaingó                        Ituzaingó
# ...                                ...                              ...
# 120767                        Belgrano                         Belgrano
# 120779                   Villa Urquiza                    Villa Urquiza
# 120783                   Villa Urquiza                    Villa Urquiza
# 120784                   Villa Urquiza                    Villa Urquiza
# 120886                        Belgrano                         Belgrano
#
#              extraído  lat_extraída  dif_lat  lon_extraída  dif_lon  \
# 1665           Moreno           NaN      NaN           NaN      NaN
# 1666        Ituzaingó    -34.663410      0.0    -58.674057      0.0
# 1677        Ituzaingó    -34.662743      0.0    -58.674038      0.0
# 1690        Ituzaingó    -34.673176      0.0    -58.671467      0.0
# 1694        Ituzaingó    -34.660198      0.0    -58.670181      0.0
# ...               ...           ...      ...           ...      ...
# 120767       Belgrano           NaN      NaN           NaN      NaN
# 120779  Villa Urquiza    -34.564638      0.0    -58.485380      0.0
# 120783  Villa Urquiza    -34.564638      0.0    -58.485380      0.0
# 120784  Villa Urquiza    -34.564638      0.0    -58.485380      0.0
# 120886       Belgrano           NaN      NaN           NaN      NaN
#
#         precio_deducido
# 1665            260.000
# 1666            115.000
# 1677            115.000
# 1690            110.000
# 1694             20.000
# ...                 ...
# 120767          693.000
# 120779           25.000
# 120783           25.000
# 120784           25.000
# 120886          693.000
#
# [274 rows x 41 columns]

# %%
data_deptos_50=(data.surface_covered_in_m2==50)&(data.property_type=="apartment")&(data.state_name=="Capital Federal")
data[data_deptos_50]
sns.scatterplot(data=data[data_deptos_50],x="expenses",y="price_aprox_usd")
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='price_aprox_usd'>

# %%
data_deptos_40=(data.surface_covered_in_m2==40)&(data.property_type=="apartment")&(data.state_name=="Capital Federal")
sns.scatterplot(data=data[data_deptos_40],x="expenses",y="price_aprox_usd")
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='price_aprox_usd'>

# %%
data_deptos_60=(data.surface_covered_in_m2==60)&(data.property_type=="apartment")&(data.state_name=="Capital Federal")
sns.scatterplot(data=data[data_deptos_60],x="expenses",y="price_aprox_usd")
# Out:
# <AxesSubplot:xlabel='expenses', ylabel='price_aprox_usd'>

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'pesos', 'país_extraído',
#        'país_extraído_sin_espacios', 'provincia_extraída',
#        'provincia_extraída_sin_espacios', 'provincia_original_sin_espacios',
#        'localidad_extraída', 'localidad_extraída_sin_espacios',
#        'localidad_original_sin_espacios', 'extraído', 'lat_extraída',
#        'dif_lat', 'lon_extraída', 'dif_lon'],
#       dtype='object')

# %%
deptos_sin_expensas=(data.expenses.isnull())&(data.property_type=="apartment")
data[deptos_sin_expensas]
# Out:
#         Unnamed: 0 operation property_type     place_name  \
# 1                1      sell     apartment       La Plata
# 2                2      sell     apartment      Mataderos
# 4                4      sell     apartment         Centro
# 7                7      sell     apartment       Belgrano
# 8                8      sell     apartment       Belgrano
# ...            ...       ...           ...            ...
# 121205      121205      sell     apartment        Córdoba
# 121206      121206      sell     apartment        Córdoba
# 121211      121211      sell     apartment       Acassuso
# 121217      121217      sell     apartment  Villa Urquiza
# 121218      121218      sell     apartment    Plaza Colón
#
#                                   place_with_parent_names country_name  \
# 1             |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 7                    |Argentina|Capital Federal|Belgrano|    Argentina
# 8                    |Argentina|Capital Federal|Belgrano|    Argentina
# ...                                                   ...          ...
# 121205                                |Argentina|Córdoba|    Argentina
# 121206                                |Argentina|Córdoba|    Argentina
# 121211  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                           state_name  geonames_id  \
# 1             Bs.As. G.B.A. Zona Sur    3432039.0
# 2                    Capital Federal    3430787.0
# 4       Buenos Aires Costa Atlántica    3435548.0
# 7                    Capital Federal    3436077.0
# 8                    Capital Federal    3436077.0
# ...                              ...          ...
# 121205                       Córdoba    3860255.0
# 121206                       Córdoba    3860255.0
# 121211      Bs.As. G.B.A. Zona Norte    3436508.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
#
#                               lat-lon        lat  ...  \
# 1             -34.9038831,-57.9643295 -34.903883  ...
# 2             -34.6522615,-58.5229825 -34.652262  ...
# 4             -38.0026256,-57.5494468 -38.002626  ...
# 7              -34.5598729,-58.443362 -34.559873  ...
# 8              -34.5598729,-58.443362 -34.559873  ...
# ...                               ...        ...  ...
# 121205                            nan        NaN  ...
# 121206                            nan        NaN  ...
# 121211                            nan        NaN  ...
# 121217  -34.5706388726,-58.4755963355 -34.570639  ...
# 121218                            nan        NaN  ...
#
#         provincia_extraída_sin_espacios  provincia_original_sin_espacios  \
# 1                Bs.As. G.B.A. Zona Sur           Bs.As. G.B.A. Zona Sur
# 2                       Capital Federal                  Capital Federal
# 4          Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# 7                       Capital Federal                  Capital Federal
# 8                       Capital Federal                  Capital Federal
# ...                                 ...                              ...
# 121205                          Córdoba                          Córdoba
# 121206                          Córdoba                          Córdoba
# 121211         Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 121217                  Capital Federal                  Capital Federal
# 121218     Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
#
#        localidad_extraída  localidad_extraída_sin_espacios  \
# 1                La Plata                         La Plata
# 2               Mataderos                        Mataderos
# 4                  Centro                           Centro
# 7                Belgrano                         Belgrano
# 8                Belgrano                         Belgrano
# ...                   ...                              ...
# 121205            Córdoba                          Córdoba
# 121206            Córdoba                          Córdoba
# 121211           Acassuso                         Acassuso
# 121217      Villa Urquiza                    Villa Urquiza
# 121218        Plaza Colón                      Plaza Colón
#
#         localidad_original_sin_espacios       extraído  lat_extraída  dif_lat  \
# 1                              La Plata       La Plata    -34.903883      0.0
# 2                             Mataderos      Mataderos    -34.652262      0.0
# 4                                Centro         Centro    -38.002626      0.0
# 7                              Belgrano       Belgrano    -34.559873      0.0
# 8                              Belgrano       Belgrano    -34.559873      0.0
# ...                                 ...            ...           ...      ...
# 121205                          Córdoba        Córdoba           NaN      NaN
# 121206                          Córdoba        Córdoba           NaN      NaN
# 121211                         Acassuso       Acassuso           NaN      NaN
# 121217                    Villa Urquiza  Villa Urquiza    -34.570639      0.0
# 121218                      Plaza Colón    Plaza Colón           NaN      NaN
#
#         lon_extraída  dif_lon
# 1         -57.964330      0.0
# 2         -58.522982      0.0
# 4         -57.549447      0.0
# 7         -58.443362      0.0
# 8         -58.443362      0.0
# ...              ...      ...
# 121205           NaN      NaN
# 121206           NaN      NaN
# 121211           NaN      NaN
# 121217    -58.475596      0.0
# 121218           NaN      NaN
#
# [59861 rows x 40 columns]

# %%
deptos_con_expensas=(data.expenses.notnull())&(data.property_type=="apartment")
data[deptos_con_expensas]
# Out:
#         Unnamed: 0 operation property_type              place_name  \
# 66              66      sell     apartment                   Boedo
# 96              96      sell     apartment            San Bernardo
# 98              98      sell     apartment                 Almagro
# 125            125      sell     apartment  Bs.As. G.B.A. Zona Sur
# 198            198      sell     apartment             Ramos Mejía
# ...            ...       ...           ...                     ...
# 121151      121151      sell     apartment                  Flores
# 121160      121160      sell     apartment                Belgrano
# 121209      121209      sell     apartment                Belgrano
# 121215      121215      sell     apartment                Belgrano
# 121219      121219      sell     apartment         Capital Federal
#
#                                   place_with_parent_names country_name  \
# 66                      |Argentina|Capital Federal|Boedo|    Argentina
# 96      |Argentina|Buenos Aires Costa Atlántica|San Be...    Argentina
# 98                    |Argentina|Capital Federal|Almagro|    Argentina
# 125                    |Argentina|Bs.As. G.B.A. Zona Sur|    Argentina
# 198     |Argentina|Bs.As. G.B.A. Zona Oeste|La Matanza...    Argentina
# ...                                                   ...          ...
# 121151                 |Argentina|Capital Federal|Flores|    Argentina
# 121160               |Argentina|Capital Federal|Belgrano|    Argentina
# 121209               |Argentina|Capital Federal|Belgrano|    Argentina
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 66                   Capital Federal    3436003.0
# 96      Buenos Aires Costa Atlántica    3429228.0
# 98                   Capital Federal    3436397.0
# 125           Bs.As. G.B.A. Zona Sur    3435907.0
# 198         Bs.As. G.B.A. Zona Oeste    3429617.0
# ...                              ...          ...
# 121151               Capital Federal    3433918.0
# 121160               Capital Federal    3436077.0
# 121209               Capital Federal    3436077.0
# 121215               Capital Federal    3436077.0
# 121219               Capital Federal    3433955.0
#
#                               lat-lon        lat  ...  \
# 66      -34.6187769485,-58.4026450688 -34.618777  ...
# 96            -36.6806689,-56.6774832 -36.680669  ...
# 98                                nan        NaN  ...
# 125             -38.416097,-63.616672 -38.416097  ...
# 198                               nan        NaN  ...
# ...                               ...        ...  ...
# 121151   -34.6295045177,-58.460641832 -34.629505  ...
# 121160   -34.563685346,-58.4426825896 -34.563685  ...
# 121209   -34.563685346,-58.4426825896 -34.563685  ...
# 121215                            nan        NaN  ...
# 121219                            nan        NaN  ...
#
#         provincia_extraída_sin_espacios  provincia_original_sin_espacios  \
# 66                      Capital Federal                  Capital Federal
# 96         Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# 98                      Capital Federal                  Capital Federal
# 125              Bs.As. G.B.A. Zona Sur           Bs.As. G.B.A. Zona Sur
# 198            Bs.As. G.B.A. Zona Oeste         Bs.As. G.B.A. Zona Oeste
# ...                                 ...                              ...
# 121151                  Capital Federal                  Capital Federal
# 121160                  Capital Federal                  Capital Federal
# 121209                  Capital Federal                  Capital Federal
# 121215                  Capital Federal                  Capital Federal
# 121219                  Capital Federal                  Capital Federal
#
#             localidad_extraída  localidad_extraída_sin_espacios  \
# 66                       Boedo                            Boedo
# 96                San Bernardo                     San Bernardo
# 98                     Almagro                          Almagro
# 125     Bs.As. G.B.A. Zona Sur           Bs.As. G.B.A. Zona Sur
# 198                Ramos Mejía                      Ramos Mejía
# ...                        ...                              ...
# 121151                  Flores                           Flores
# 121160                Belgrano                         Belgrano
# 121209                Belgrano                         Belgrano
# 121215                Belgrano                         Belgrano
# 121219         Capital Federal                  Capital Federal
#
#         localidad_original_sin_espacios                extraído  lat_extraída  \
# 66                                Boedo                   Boedo    -34.618777
# 96                         San Bernardo            San Bernardo    -36.680669
# 98                              Almagro                 Almagro           NaN
# 125              Bs.As. G.B.A. Zona Sur  Bs.As. G.B.A. Zona Sur    -38.416097
# 198                         Ramos Mejía             Ramos Mejía           NaN
# ...                                 ...                     ...           ...
# 121151                           Flores                  Flores    -34.629505
# 121160                         Belgrano                Belgrano    -34.563685
# 121209                         Belgrano                Belgrano    -34.563685
# 121215                         Belgrano                Belgrano           NaN
# 121219                  Capital Federal         Capital Federal           NaN
#
#         dif_lat  lon_extraída  dif_lon
# 66          0.0    -58.402645      0.0
# 96          0.0    -56.677483      0.0
# 98          NaN           NaN      NaN
# 125         0.0    -63.616672      0.0
# 198         NaN           NaN      NaN
# ...         ...           ...      ...
# 121151      0.0    -58.460642      0.0
# 121160      0.0    -58.442683      0.0
# 121209      0.0    -58.442683      0.0
# 121215      NaN           NaN      NaN
# 121219      NaN           NaN      NaN
#
# [11204 rows x 40 columns]

# %%
data.expenses.isnull().sum()
# Out:
# 106958

# %%
pattern_expensas="expensas"
pattern_expensas_regex=re.compile(pattern_expensas)
pattern_expensas_match=data[data.expenses.isnull()]["description"].apply(lambda x: x if x is np.NaN else pattern_expensas_regex.search(x))
print(pattern_expensas_match.isnull().sum(),pattern_expensas_match.notnull().sum())
pattern_expensas_match_not_null=pattern_expensas_match.notnull()
data[data.expenses.isnull()][pattern_expensas_match_not_null]
# Out:
# 100316 6642
#         Unnamed: 0 operation property_type   place_name  \
# 34              34      sell            PH        Munro
# 35              35      sell     apartment        Boedo
# 43              43      sell     apartment        Pilar
# 114            114      sell     apartment   San Isidro
# 137            137      sell            PH   Colegiales
# ...            ...       ...           ...          ...
# 121069      121069      sell         house  San Lorenzo
# 121104      121104      sell            PH        Tigre
# 121128      121128      sell     apartment     Belgrano
# 121157      121157      sell     apartment     Belgrano
# 121216      121216      sell         house       Beccar
#
#                                   place_with_parent_names country_name  \
# 34      |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 35                      |Argentina|Capital Federal|Boedo|    Argentina
# 43             |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 114       |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|    Argentina
# 137                |Argentina|Capital Federal|Colegiales|    Argentina
# ...                                                   ...          ...
# 121069                   |Argentina|Santa Fe|San Lorenzo|    Argentina
# 121104         |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 121128               |Argentina|Capital Federal|Belgrano|    Argentina
# 121157               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 34      Bs.As. G.B.A. Zona Norte    3430511.0        -34.5272528,-58.5128766
# 35               Capital Federal    3436003.0  -34.6217693287,-58.4221081951
# 43      Bs.As. G.B.A. Zona Norte    3429979.0  -34.4394337814,-58.7987030039
# 114     Bs.As. G.B.A. Zona Norte    3428983.0                            nan
# 137              Capital Federal    3435356.0          -34.579394,-58.445882
# ...                          ...          ...                            ...
# 121069                  Santa Fe    3837090.0                            nan
# 121104  Bs.As. G.B.A. Zona Norte    3427753.0                            nan
# 121128           Capital Federal    3436077.0  -34.5568648226,-58.4477064427
# 121157           Capital Federal    3436077.0                            nan
# 121216  Bs.As. G.B.A. Zona Norte    3436080.0                            nan
#
#               lat  ...  provincia_extraída_sin_espacios  \
# 34     -34.527253  ...         Bs.As. G.B.A. Zona Norte
# 35     -34.621769  ...                  Capital Federal
# 43     -34.439434  ...         Bs.As. G.B.A. Zona Norte
# 114           NaN  ...         Bs.As. G.B.A. Zona Norte
# 137    -34.579394  ...                  Capital Federal
# ...           ...  ...                              ...
# 121069        NaN  ...                         Santa Fe
# 121104        NaN  ...         Bs.As. G.B.A. Zona Norte
# 121128 -34.556865  ...                  Capital Federal
# 121157        NaN  ...                  Capital Federal
# 121216        NaN  ...         Bs.As. G.B.A. Zona Norte
#
#         provincia_original_sin_espacios localidad_extraída  \
# 34             Bs.As. G.B.A. Zona Norte              Munro
# 35                      Capital Federal              Boedo
# 43             Bs.As. G.B.A. Zona Norte              Pilar
# 114            Bs.As. G.B.A. Zona Norte         San Isidro
# 137                     Capital Federal         Colegiales
# ...                                 ...                ...
# 121069                         Santa Fe        San Lorenzo
# 121104         Bs.As. G.B.A. Zona Norte              Tigre
# 121128                  Capital Federal           Belgrano
# 121157                  Capital Federal           Belgrano
# 121216         Bs.As. G.B.A. Zona Norte             Beccar
#
#         localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 34                                Munro                            Munro
# 35                                Boedo                            Boedo
# 43                                Pilar                            Pilar
# 114                          San Isidro                       San Isidro
# 137                          Colegiales                       Colegiales
# ...                                 ...                              ...
# 121069                      San Lorenzo                      San Lorenzo
# 121104                            Tigre                            Tigre
# 121128                         Belgrano                         Belgrano
# 121157                         Belgrano                         Belgrano
# 121216                           Beccar                           Beccar
#
#            extraído  lat_extraída  dif_lat  lon_extraída  dif_lon
# 34            Munro    -34.527253      0.0    -58.512877      0.0
# 35            Boedo    -34.621769      0.0    -58.422108      0.0
# 43            Pilar    -34.439434      0.0    -58.798703      0.0
# 114      San Isidro           NaN      NaN           NaN      NaN
# 137      Colegiales    -34.579394      0.0    -58.445882      0.0
# ...             ...           ...      ...           ...      ...
# 121069  San Lorenzo           NaN      NaN           NaN      NaN
# 121104        Tigre           NaN      NaN           NaN      NaN
# 121128     Belgrano    -34.556865      0.0    -58.447706      0.0
# 121157     Belgrano           NaN      NaN           NaN      NaN
# 121216       Beccar           NaN      NaN           NaN      NaN
#
# [6642 rows x 40 columns]

# %%
pattern_expensas2="expensas.\$"
pattern_expensas2_regex=re.compile(pattern_expensas2)
pattern_expensas2_match=data[data.expenses.isnull()]["description"].apply(lambda x: x if x is np.NaN else pattern_expensas2_regex.search(x))
print(pattern_expensas2_match.isnull().sum(),pattern_expensas2_match.notnull().sum())
pattern_expensas2_match_not_null=pattern_expensas2_match.notnull()
data[data.expenses.isnull()][pattern_expensas2_match_not_null]
# Out:
# 106810 148
#         Unnamed: 0 operation property_type     place_name  \
# 114            114      sell     apartment     San Isidro
# 166            166      sell     apartment      Caballito
# 284            284      sell     apartment  Mar del Plata
# 397            397      sell     apartment   San Fernando
# 476            476      sell     apartment  Villa Urquiza
# ...            ...       ...           ...            ...
# 116973      116973      sell     apartment      Balvanera
# 118708      118708      sell     apartment  Mar del Plata
# 119810      119810      sell     apartment      Caballito
# 120805      120805      sell     apartment      Caballito
# 120861      120861      sell            PH      Caballito
#
#                                   place_with_parent_names country_name  \
# 114       |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro|    Argentina
# 166                 |Argentina|Capital Federal|Caballito|    Argentina
# 284     |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 397     |Argentina|Bs.As. G.B.A. Zona Norte|San Fernando|    Argentina
# 476             |Argentina|Capital Federal|Villa Urquiza|    Argentina
# ...                                                   ...          ...
# 116973              |Argentina|Capital Federal|Balvanera|    Argentina
# 118708  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 119810              |Argentina|Capital Federal|Caballito|    Argentina
# 120805              |Argentina|Capital Federal|Caballito|    Argentina
# 120861              |Argentina|Capital Federal|Caballito|    Argentina
#
#                           state_name  geonames_id  \
# 114         Bs.As. G.B.A. Zona Norte    3428983.0
# 166                  Capital Federal    3435874.0
# 284     Buenos Aires Costa Atlántica    3430863.0
# 397         Bs.As. G.B.A. Zona Norte    3429088.0
# 476                  Capital Federal    3433775.0
# ...                              ...          ...
# 116973               Capital Federal    6693228.0
# 118708  Buenos Aires Costa Atlántica    3430863.0
# 119810               Capital Federal    3435874.0
# 120805               Capital Federal    3435874.0
# 120861               Capital Federal    3435874.0
#
#                               lat-lon        lat  ...  \
# 114                               nan        NaN  ...
# 166             -34.620725,-58.438704 -34.620725  ...
# 284           -38.0015549,-57.5471808 -38.001555  ...
# 397        -34.435338186,-58.56545421 -34.435338  ...
# 476             -34.572645,-58.482177 -34.572645  ...
# ...                               ...        ...  ...
# 116973         -34.614164,-58.3937716 -34.614164  ...
# 118708        -37.9869946,-57.5456242 -37.986995  ...
# 119810        -34.6209278,-58.4458736 -34.620928  ...
# 120805                            nan        NaN  ...
# 120861  -34.6228133964,-58.4333933138 -34.622813  ...
#
#         provincia_extraída_sin_espacios  provincia_original_sin_espacios  \
# 114            Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 166                     Capital Federal                  Capital Federal
# 284        Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# 397            Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 476                     Capital Federal                  Capital Federal
# ...                                 ...                              ...
# 116973                  Capital Federal                  Capital Federal
# 118708     Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# 119810                  Capital Federal                  Capital Federal
# 120805                  Capital Federal                  Capital Federal
# 120861                  Capital Federal                  Capital Federal
#
#        localidad_extraída  localidad_extraída_sin_espacios  \
# 114            San Isidro                       San Isidro
# 166             Caballito                        Caballito
# 284         Mar del Plata                    Mar del Plata
# 397          San Fernando                     San Fernando
# 476         Villa Urquiza                    Villa Urquiza
# ...                   ...                              ...
# 116973          Balvanera                        Balvanera
# 118708      Mar del Plata                    Mar del Plata
# 119810          Caballito                        Caballito
# 120805          Caballito                        Caballito
# 120861          Caballito                        Caballito
#
#         localidad_original_sin_espacios       extraído  lat_extraída  dif_lat  \
# 114                          San Isidro     San Isidro           NaN      NaN
# 166                           Caballito      Caballito    -34.620725      0.0
# 284                       Mar del Plata  Mar del Plata    -38.001555      0.0
# 397                        San Fernando   San Fernando    -34.435338      0.0
# 476                       Villa Urquiza  Villa Urquiza    -34.572645      0.0
# ...                                 ...            ...           ...      ...
# 116973                        Balvanera      Balvanera    -34.614164      0.0
# 118708                    Mar del Plata  Mar del Plata    -37.986995      0.0
# 119810                        Caballito      Caballito    -34.620928      0.0
# 120805                        Caballito      Caballito           NaN      NaN
# 120861                        Caballito      Caballito    -34.622813      0.0
#
#         lon_extraída  dif_lon
# 114              NaN      NaN
# 166       -58.438704      0.0
# 284       -57.547181      0.0
# 397       -58.565454      0.0
# 476       -58.482177      0.0
# ...              ...      ...
# 116973    -58.393772      0.0
# 118708    -57.545624      0.0
# 119810    -58.445874      0.0
# 120805           NaN      NaN
# 120861    -58.433393      0.0
#
# [148 rows x 40 columns]

# %%
#Conclusión sobre expensas. Probablemente haya alguna correlación, pero tb puede ser por variable omitida. 
# Difícil de completar con regex, aún pudiendo tpoco cambia sustancialmente el número de notnull.

# %%
pattern_m2="m2"
pattern_m2_regex=re.compile(pattern_m2)
pattern_m2_match=data[(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.isnull())]["description"].apply(lambda x: x if x is np.NaN else pattern_m2_regex.search(x))
print(pattern_m2_match.isnull().sum(),pattern_m2_match.notnull().sum())
pattern_m2_match_not_null=pattern_m2_match.notnull()
data[(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.isnull())][pattern_m2_match_not_null]
#De los 12.369 con viento a favor podríamos llenar 1.748.
# Out:
# 10621 1748
#         Unnamed: 0 operation property_type               place_name  \
# 175            175      sell     apartment              Confluencia
# 337            337      sell         house  San Carlos de Bariloche
# 369            369      sell         house  San Martín de los Andes
# 526            526      sell     apartment                  Rosario
# 538            538      sell     apartment                  Rosario
# ...            ...       ...           ...                      ...
# 120103      120103      sell     apartment                  Rosario
# 120122      120122      sell     apartment            Mar del Plata
# 120523      120523      sell         store                  Córdoba
# 120634      120634      sell         house                  Córdoba
# 120653      120653      sell     apartment                  Córdoba
#
#                                   place_with_parent_names country_name  \
# 175                       |Argentina|Neuquén|Confluencia|    Argentina
# 337     |Argentina|Río Negro|San Carlos de Bariloche|S...    Argentina
# 369           |Argentina|Neuquén|San Martín de los Andes|    Argentina
# 526                          |Argentina|Santa Fe|Rosario|    Argentina
# 538                          |Argentina|Santa Fe|Rosario|    Argentina
# ...                                                   ...          ...
# 120103                       |Argentina|Santa Fe|Rosario|    Argentina
# 120122  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 120523                        |Argentina|Córdoba|Córdoba|    Argentina
# 120634                        |Argentina|Córdoba|Córdoba|    Argentina
# 120653                                |Argentina|Córdoba|    Argentina
#
#                           state_name  geonames_id                  lat-lon  \
# 175                          Neuquén    3860360.0    -38.974274,-68.019125
# 337                        Río Negro    3837856.0    -41.169464,-71.386778
# 369                          Neuquén    3836951.0                      nan
# 526                         Santa Fe    3838574.0  -32.9534884,-60.6281943
# 538                         Santa Fe    3838574.0  -32.9610051,-60.6272702
# ...                              ...          ...                      ...
# 120103                      Santa Fe    3838574.0  -32.9573736,-60.6277937
# 120122  Buenos Aires Costa Atlántica    3430863.0  -38.0054923,-57.5525794
# 120523                       Córdoba    3860259.0                      nan
# 120634                       Córdoba    3860259.0                      nan
# 120653                       Córdoba    3860255.0                      nan
#
#               lat  ...  provincia_extraída_sin_espacios  \
# 175    -38.974274  ...                          Neuquén
# 337    -41.169464  ...                        Río Negro
# 369           NaN  ...                          Neuquén
# 526    -32.953488  ...                         Santa Fe
# 538    -32.961005  ...                         Santa Fe
# ...           ...  ...                              ...
# 120103 -32.957374  ...                         Santa Fe
# 120122 -38.005492  ...     Buenos Aires Costa Atlántica
# 120523        NaN  ...                          Córdoba
# 120634        NaN  ...                          Córdoba
# 120653        NaN  ...                          Córdoba
#
#         provincia_original_sin_espacios       localidad_extraída  \
# 175                             Neuquén              Confluencia
# 337                           Río Negro  San Carlos de Bariloche
# 369                             Neuquén  San Martín de los Andes
# 526                            Santa Fe                  Rosario
# 538                            Santa Fe                  Rosario
# ...                                 ...                      ...
# 120103                         Santa Fe                  Rosario
# 120122     Buenos Aires Costa Atlántica            Mar del Plata
# 120523                          Córdoba                  Córdoba
# 120634                          Córdoba                  Córdoba
# 120653                          Córdoba                  Córdoba
#
#         localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 175                         Confluencia                      Confluencia
# 337             San Carlos de Bariloche          San Carlos de Bariloche
# 369             San Martín de los Andes          San Martín de los Andes
# 526                             Rosario                          Rosario
# 538                             Rosario                          Rosario
# ...                                 ...                              ...
# 120103                          Rosario                          Rosario
# 120122                    Mar del Plata                    Mar del Plata
# 120523                          Córdoba                          Córdoba
# 120634                          Córdoba                          Córdoba
# 120653                          Córdoba                          Córdoba
#
#                        extraído  lat_extraída  dif_lat  lon_extraída  dif_lon
# 175                 Confluencia    -38.974274      0.0    -68.019125      0.0
# 337     San Carlos de Bariloche    -41.169464      0.0    -71.386778      0.0
# 369     San Martín de los Andes           NaN      NaN           NaN      NaN
# 526                     Rosario    -32.953488      0.0    -60.628194      0.0
# 538                     Rosario    -32.961005      0.0    -60.627270      0.0
# ...                         ...           ...      ...           ...      ...
# 120103                  Rosario    -32.957374      0.0    -60.627794      0.0
# 120122            Mar del Plata    -38.005492      0.0    -57.552579      0.0
# 120523                  Córdoba           NaN      NaN           NaN      NaN
# 120634                  Córdoba           NaN      NaN           NaN      NaN
# 120653                  Córdoba           NaN      NaN           NaN      NaN
#
# [1748 rows x 40 columns]

# %%
data_sin_superficie_cubierta_pero_con_superficie_total=(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.notnull())
data[data_sin_superficie_cubierta_pero_con_superficie_total]
# Out:
#         Unnamed: 0 operation property_type    place_name  \
# 5                5      sell         house  Gualeguaychú
# 10              10      sell         house       Córdoba
# 15              15      sell         house   Bella Vista
# 66              66      sell     apartment         Boedo
# 67              67      sell         house     Ituzaingó
# ...            ...       ...           ...           ...
# 121203      121203      sell     apartment       Córdoba
# 121204      121204      sell     apartment       Córdoba
# 121205      121205      sell     apartment       Córdoba
# 121206      121206      sell     apartment       Córdoba
# 121209      121209      sell     apartment      Belgrano
#
#                                   place_with_parent_names country_name  \
# 5                     |Argentina|Entre Ríos|Gualeguaychú|    Argentina
# 10                            |Argentina|Córdoba|Córdoba|    Argentina
# 15      |Argentina|Bs.As. G.B.A. Zona Norte|San Miguel...    Argentina
# 66                      |Argentina|Capital Federal|Boedo|    Argentina
# 67         |Argentina|Bs.As. G.B.A. Zona Oeste|Ituzaingó|    Argentina
# ...                                                   ...          ...
# 121203                                |Argentina|Córdoba|    Argentina
# 121204                                |Argentina|Córdoba|    Argentina
# 121205                                |Argentina|Córdoba|    Argentina
# 121206                                |Argentina|Córdoba|    Argentina
# 121209               |Argentina|Capital Federal|Belgrano|    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 5                     Entre Ríos    3433657.0         -33.0140714,-58.519828
# 10                       Córdoba    3860259.0        -31.4200833,-64.1887761
# 15      Bs.As. G.B.A. Zona Norte    3436061.0  -34.5879112015,-58.6987828445
# 66               Capital Federal    3436003.0  -34.6187769485,-58.4026450688
# 67      Bs.As. G.B.A. Zona Oeste    3433359.0        -34.6422298,-58.7031296
# ...                          ...          ...                            ...
# 121203                   Córdoba    3860255.0                            nan
# 121204                   Córdoba    3860255.0                            nan
# 121205                   Córdoba    3860255.0                            nan
# 121206                   Córdoba    3860255.0                            nan
# 121209           Capital Federal    3436077.0   -34.563685346,-58.4426825896
#
#               lat  ...  provincia_extraída_sin_espacios  \
# 5      -33.014071  ...                       Entre Ríos
# 10     -31.420083  ...                          Córdoba
# 15     -34.587911  ...         Bs.As. G.B.A. Zona Norte
# 66     -34.618777  ...                  Capital Federal
# 67     -34.642230  ...         Bs.As. G.B.A. Zona Oeste
# ...           ...  ...                              ...
# 121203        NaN  ...                          Córdoba
# 121204        NaN  ...                          Córdoba
# 121205        NaN  ...                          Córdoba
# 121206        NaN  ...                          Córdoba
# 121209 -34.563685  ...                  Capital Federal
#
#         provincia_original_sin_espacios localidad_extraída  \
# 5                            Entre Ríos       Gualeguaychú
# 10                              Córdoba            Córdoba
# 15             Bs.As. G.B.A. Zona Norte        Bella Vista
# 66                      Capital Federal              Boedo
# 67             Bs.As. G.B.A. Zona Oeste          Ituzaingó
# ...                                 ...                ...
# 121203                          Córdoba            Córdoba
# 121204                          Córdoba            Córdoba
# 121205                          Córdoba            Córdoba
# 121206                          Córdoba            Córdoba
# 121209                  Capital Federal           Belgrano
#
#         localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 5                          Gualeguaychú                     Gualeguaychú
# 10                              Córdoba                          Córdoba
# 15                          Bella Vista                      Bella Vista
# 66                                Boedo                            Boedo
# 67                            Ituzaingó                        Ituzaingó
# ...                                 ...                              ...
# 121203                          Córdoba                          Córdoba
# 121204                          Córdoba                          Córdoba
# 121205                          Córdoba                          Córdoba
# 121206                          Córdoba                          Córdoba
# 121209                         Belgrano                         Belgrano
#
#             extraído  lat_extraída  dif_lat  lon_extraída  dif_lon
# 5       Gualeguaychú    -33.014071      0.0    -58.519828      0.0
# 10           Córdoba    -31.420083      0.0    -64.188776      0.0
# 15       Bella Vista    -34.587911      0.0    -58.698783      0.0
# 66             Boedo    -34.618777      0.0    -58.402645      0.0
# 67         Ituzaingó    -34.642230      0.0    -58.703130      0.0
# ...              ...           ...      ...           ...      ...
# 121203       Córdoba           NaN      NaN           NaN      NaN
# 121204       Córdoba           NaN      NaN           NaN      NaN
# 121205       Córdoba           NaN      NaN           NaN      NaN
# 121206       Córdoba           NaN      NaN           NaN      NaN
# 121209      Belgrano    -34.563685      0.0    -58.442683      0.0
#
# [7538 rows x 40 columns]

# %%
data_sin_superficie_total_pero_con_superficie_cubierta=(data.surface_covered_in_m2.notnull())&(data.surface_total_in_m2.isnull())
data[data_sin_superficie_total_pero_con_superficie_cubierta]
# Out:
#         Unnamed: 0 operation property_type     place_name  \
# 68              68      sell     apartment  Mar del Plata
# 77              77      sell     apartment  Mar del Plata
# 79              79      sell     apartment  Mar del Plata
# 87              87      sell         house        Córdoba
# 89              89      sell     apartment        Córdoba
# ...            ...       ...           ...            ...
# 121155      121155      sell         house          Pilar
# 121156      121156      sell         house          Pilar
# 121207      121207      sell         house        Escobar
# 121208      121208      sell         house        Escobar
# 121210      121210      sell         house       Martínez
#
#                                   place_with_parent_names country_name  \
# 68      |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 77      |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 79      |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 87                            |Argentina|Córdoba|Córdoba|    Argentina
# 89                            |Argentina|Córdoba|Córdoba|    Argentina
# ...                                                   ...          ...
# 121155         |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 121156         |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|    Argentina
# 121207       |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|    Argentina
# 121208       |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|    Argentina
# 121210  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
#
#                           state_name  geonames_id                  lat-lon  \
# 68      Buenos Aires Costa Atlántica    3430863.0   -38.034794,-57.5416872
# 77      Buenos Aires Costa Atlántica    3430863.0  -38.0034731,-57.5501571
# 79      Buenos Aires Costa Atlántica    3430863.0    -38.0041665,-57.55775
# 87                           Córdoba    3860259.0  -31.4253708,-64.1577465
# 89                           Córdoba    3860259.0   -31.4283549,-64.205149
# ...                              ...          ...                      ...
# 121155      Bs.As. G.B.A. Zona Norte    3429979.0                      nan
# 121156      Bs.As. G.B.A. Zona Norte    3429979.0                      nan
# 121207      Bs.As. G.B.A. Zona Norte    3434130.0                      nan
# 121208      Bs.As. G.B.A. Zona Norte    3434130.0                      nan
# 121210      Bs.As. G.B.A. Zona Norte    3430813.0                      nan
#
#               lat  ...  provincia_extraída_sin_espacios  \
# 68     -38.034794  ...     Buenos Aires Costa Atlántica
# 77     -38.003473  ...     Buenos Aires Costa Atlántica
# 79     -38.004166  ...     Buenos Aires Costa Atlántica
# 87     -31.425371  ...                          Córdoba
# 89     -31.428355  ...                          Córdoba
# ...           ...  ...                              ...
# 121155        NaN  ...         Bs.As. G.B.A. Zona Norte
# 121156        NaN  ...         Bs.As. G.B.A. Zona Norte
# 121207        NaN  ...         Bs.As. G.B.A. Zona Norte
# 121208        NaN  ...         Bs.As. G.B.A. Zona Norte
# 121210        NaN  ...         Bs.As. G.B.A. Zona Norte
#
#         provincia_original_sin_espacios localidad_extraída  \
# 68         Buenos Aires Costa Atlántica      Mar del Plata
# 77         Buenos Aires Costa Atlántica      Mar del Plata
# 79         Buenos Aires Costa Atlántica      Mar del Plata
# 87                              Córdoba            Córdoba
# 89                              Córdoba            Córdoba
# ...                                 ...                ...
# 121155         Bs.As. G.B.A. Zona Norte              Pilar
# 121156         Bs.As. G.B.A. Zona Norte              Pilar
# 121207         Bs.As. G.B.A. Zona Norte            Escobar
# 121208         Bs.As. G.B.A. Zona Norte            Escobar
# 121210         Bs.As. G.B.A. Zona Norte           Martínez
#
#         localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 68                        Mar del Plata                    Mar del Plata
# 77                        Mar del Plata                    Mar del Plata
# 79                        Mar del Plata                    Mar del Plata
# 87                              Córdoba                          Córdoba
# 89                              Córdoba                          Córdoba
# ...                                 ...                              ...
# 121155                            Pilar                            Pilar
# 121156                            Pilar                            Pilar
# 121207                          Escobar                          Escobar
# 121208                          Escobar                          Escobar
# 121210                         Martínez                         Martínez
#
#              extraído  lat_extraída  dif_lat  lon_extraída  dif_lon
# 68      Mar del Plata    -38.034794      0.0    -57.541687      0.0
# 77      Mar del Plata    -38.003473      0.0    -57.550157      0.0
# 79      Mar del Plata    -38.004166      0.0    -57.557750      0.0
# 87            Córdoba    -31.425371      0.0    -64.157746      0.0
# 89            Córdoba    -31.428355      0.0    -64.205149      0.0
# ...               ...           ...      ...           ...      ...
# 121155          Pilar           NaN      NaN           NaN      NaN
# 121156          Pilar           NaN      NaN           NaN      NaN
# 121207        Escobar           NaN      NaN           NaN      NaN
# 121208        Escobar           NaN      NaN           NaN      NaN
# 121210       Martínez           NaN      NaN           NaN      NaN
#
# [26959 rows x 40 columns]

# %%
pattern_m2="m2"
pattern_m2_regex=re.compile(pattern_m2)
pattern_m2_match=data[(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.notnull())]["description"].apply(lambda x: x if x is np.NaN else pattern_m2_regex.search(x))
print(pattern_m2_match.isnull().sum(),pattern_m2_match.notnull().sum())
pattern_m2_match_not_null=pattern_m2_match.notnull()
data[(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.notnull())][pattern_m2_match_not_null]
#De los 12.369 con viento a favor podríamos llenar 1.748.
# Out:
# 6193 1345
#         Unnamed: 0 operation property_type                 place_name  \
# 101            101      sell     apartment                    Rosario
# 102            102      sell     apartment                    Rosario
# 202            202      sell         house        Estancias del Pilar
# 336            336      sell     apartment                    Córdoba
# 424            424      sell     apartment              Mar del Plata
# ...            ...       ...           ...                        ...
# 120063      120063      sell     apartment                      Luján
# 120076      120076      sell         store                    Córdoba
# 120156      120156      sell         house  Barrio Barrancas del Lago
# 121126      121126      sell     apartment                    Córdoba
# 121129      121129      sell     apartment                    Córdoba
#
#                                   place_with_parent_names country_name  \
# 101                          |Argentina|Santa Fe|Rosario|    Argentina
# 102                          |Argentina|Santa Fe|Rosario|    Argentina
# 202     |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Esta...    Argentina
# 336                           |Argentina|Córdoba|Córdoba|    Argentina
# 424     |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...                                                   ...          ...
# 120063      |Argentina|Buenos Aires Interior|Luján|Luján|    Argentina
# 120076                                |Argentina|Córdoba|    Argentina
# 120156  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 121126                                |Argentina|Córdoba|    Argentina
# 121129                                |Argentina|Córdoba|    Argentina
#
#                           state_name  geonames_id  \
# 101                         Santa Fe    3838574.0
# 102                         Santa Fe    3838574.0
# 202         Bs.As. G.B.A. Zona Norte          NaN
# 336                          Córdoba    3860259.0
# 424     Buenos Aires Costa Atlántica    3430863.0
# ...                              ...          ...
# 120063         Buenos Aires Interior    3430982.0
# 120076                       Córdoba    3860255.0
# 120156      Bs.As. G.B.A. Zona Norte          NaN
# 121126                       Córdoba    3860255.0
# 121129                       Córdoba    3860255.0
#
#                               lat-lon        lat  ...  \
# 101     -32.9359588621,-60.6691426017 -32.935959  ...
# 102     -32.9359588621,-60.6691426017 -32.935959  ...
# 202           -34.4804129,-58.9920461 -34.480413  ...
# 336            -31.3621643,-64.237574 -31.362164  ...
# 424           -38.0009579,-57.5596234 -38.000958  ...
# ...                               ...        ...  ...
# 120063                            nan        NaN  ...
# 120076                            nan        NaN  ...
# 120156  -34.4070396202,-58.6768333755 -34.407040  ...
# 121126                            nan        NaN  ...
# 121129                            nan        NaN  ...
#
#         provincia_extraída_sin_espacios  provincia_original_sin_espacios  \
# 101                            Santa Fe                         Santa Fe
# 102                            Santa Fe                         Santa Fe
# 202            Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 336                             Córdoba                          Córdoba
# 424        Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# ...                                 ...                              ...
# 120063            Buenos Aires Interior            Buenos Aires Interior
# 120076                          Córdoba                          Córdoba
# 120156         Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 121126                          Córdoba                          Córdoba
# 121129                          Córdoba                          Córdoba
#
#                localidad_extraída  localidad_extraída_sin_espacios  \
# 101                       Rosario                          Rosario
# 102                       Rosario                          Rosario
# 202           Estancias del Pilar              Estancias del Pilar
# 336                       Córdoba                          Córdoba
# 424                 Mar del Plata                    Mar del Plata
# ...                           ...                              ...
# 120063                      Luján                            Luján
# 120076                    Córdoba                          Córdoba
# 120156  Barrio Barrancas del Lago        Barrio Barrancas del Lago
# 121126                    Córdoba                          Córdoba
# 121129                    Córdoba                          Córdoba
#
#         localidad_original_sin_espacios                   extraído  \
# 101                             Rosario                    Rosario
# 102                             Rosario                    Rosario
# 202                 Estancias del Pilar        Estancias del Pilar
# 336                             Córdoba                    Córdoba
# 424                       Mar del Plata              Mar del Plata
# ...                                 ...                        ...
# 120063                            Luján                      Luján
# 120076                          Córdoba                    Córdoba
# 120156        Barrio Barrancas del Lago  Barrio Barrancas del Lago
# 121126                          Córdoba                    Córdoba
# 121129                          Córdoba                    Córdoba
#
#         lat_extraída  dif_lat  lon_extraída  dif_lon
# 101       -32.935959      0.0    -60.669143      0.0
# 102       -32.935959      0.0    -60.669143      0.0
# 202       -34.480413      0.0    -58.992046      0.0
# 336       -31.362164      0.0    -64.237574      0.0
# 424       -38.000958      0.0    -57.559623      0.0
# ...              ...      ...           ...      ...
# 120063           NaN      NaN           NaN      NaN
# 120076           NaN      NaN           NaN      NaN
# 120156    -34.407040      0.0    -58.676833      0.0
# 121126           NaN      NaN           NaN      NaN
# 121129           NaN      NaN           NaN      NaN
#
# [1345 rows x 40 columns]

# %%
pattern_m2_2="m2"
pattern_m2_2_regex=re.compile(pattern_m2_2)
pattern_m2_2_match=data[(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.notnull())]["description"].apply(lambda x: x if x is np.NaN else pattern_m2_2_regex.search(x))
print(pattern_m2_2_match.isnull().sum(),pattern_m2_2_match.notnull().sum())
pattern_m2_2_match_not_null=pattern_m2_2_match.notnull()
data[(data.surface_covered_in_m2.isnull())&(data.surface_total_in_m2.notnull())][pattern_m2_2_match_not_null]
#De los 12.369 con viento a favor podríamos llenar 1.345.
# Out:
# 6193 1345
#         Unnamed: 0 operation property_type                 place_name  \
# 101            101      sell     apartment                    Rosario
# 102            102      sell     apartment                    Rosario
# 202            202      sell         house        Estancias del Pilar
# 336            336      sell     apartment                    Córdoba
# 424            424      sell     apartment              Mar del Plata
# ...            ...       ...           ...                        ...
# 120063      120063      sell     apartment                      Luján
# 120076      120076      sell         store                    Córdoba
# 120156      120156      sell         house  Barrio Barrancas del Lago
# 121126      121126      sell     apartment                    Córdoba
# 121129      121129      sell     apartment                    Córdoba
#
#                                   place_with_parent_names country_name  \
# 101                          |Argentina|Santa Fe|Rosario|    Argentina
# 102                          |Argentina|Santa Fe|Rosario|    Argentina
# 202     |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Esta...    Argentina
# 336                           |Argentina|Córdoba|Córdoba|    Argentina
# 424     |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# ...                                                   ...          ...
# 120063      |Argentina|Buenos Aires Interior|Luján|Luján|    Argentina
# 120076                                |Argentina|Córdoba|    Argentina
# 120156  |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|Nord...    Argentina
# 121126                                |Argentina|Córdoba|    Argentina
# 121129                                |Argentina|Córdoba|    Argentina
#
#                           state_name  geonames_id  \
# 101                         Santa Fe    3838574.0
# 102                         Santa Fe    3838574.0
# 202         Bs.As. G.B.A. Zona Norte          NaN
# 336                          Córdoba    3860259.0
# 424     Buenos Aires Costa Atlántica    3430863.0
# ...                              ...          ...
# 120063         Buenos Aires Interior    3430982.0
# 120076                       Córdoba    3860255.0
# 120156      Bs.As. G.B.A. Zona Norte          NaN
# 121126                       Córdoba    3860255.0
# 121129                       Córdoba    3860255.0
#
#                               lat-lon        lat  ...  \
# 101     -32.9359588621,-60.6691426017 -32.935959  ...
# 102     -32.9359588621,-60.6691426017 -32.935959  ...
# 202           -34.4804129,-58.9920461 -34.480413  ...
# 336            -31.3621643,-64.237574 -31.362164  ...
# 424           -38.0009579,-57.5596234 -38.000958  ...
# ...                               ...        ...  ...
# 120063                            nan        NaN  ...
# 120076                            nan        NaN  ...
# 120156  -34.4070396202,-58.6768333755 -34.407040  ...
# 121126                            nan        NaN  ...
# 121129                            nan        NaN  ...
#
#         provincia_extraída_sin_espacios  provincia_original_sin_espacios  \
# 101                            Santa Fe                         Santa Fe
# 102                            Santa Fe                         Santa Fe
# 202            Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 336                             Córdoba                          Córdoba
# 424        Buenos Aires Costa Atlántica     Buenos Aires Costa Atlántica
# ...                                 ...                              ...
# 120063            Buenos Aires Interior            Buenos Aires Interior
# 120076                          Córdoba                          Córdoba
# 120156         Bs.As. G.B.A. Zona Norte         Bs.As. G.B.A. Zona Norte
# 121126                          Córdoba                          Córdoba
# 121129                          Córdoba                          Córdoba
#
#                localidad_extraída  localidad_extraída_sin_espacios  \
# 101                       Rosario                          Rosario
# 102                       Rosario                          Rosario
# 202           Estancias del Pilar              Estancias del Pilar
# 336                       Córdoba                          Córdoba
# 424                 Mar del Plata                    Mar del Plata
# ...                           ...                              ...
# 120063                      Luján                            Luján
# 120076                    Córdoba                          Córdoba
# 120156  Barrio Barrancas del Lago        Barrio Barrancas del Lago
# 121126                    Córdoba                          Córdoba
# 121129                    Córdoba                          Córdoba
#
#         localidad_original_sin_espacios                   extraído  \
# 101                             Rosario                    Rosario
# 102                             Rosario                    Rosario
# 202                 Estancias del Pilar        Estancias del Pilar
# 336                             Córdoba                    Córdoba
# 424                       Mar del Plata              Mar del Plata
# ...                                 ...                        ...
# 120063                            Luján                      Luján
# 120076                          Córdoba                    Córdoba
# 120156        Barrio Barrancas del Lago  Barrio Barrancas del Lago
# 121126                          Córdoba                    Córdoba
# 121129                          Córdoba                    Córdoba
#
#         lat_extraída  dif_lat  lon_extraída  dif_lon
# 101       -32.935959      0.0    -60.669143      0.0
# 102       -32.935959      0.0    -60.669143      0.0
# 202       -34.480413      0.0    -58.992046      0.0
# 336       -31.362164      0.0    -64.237574      0.0
# 424       -38.000958      0.0    -57.559623      0.0
# ...              ...      ...           ...      ...
# 120063           NaN      NaN           NaN      NaN
# 120076           NaN      NaN           NaN      NaN
# 120156    -34.407040      0.0    -58.676833      0.0
# 121126           NaN      NaN           NaN      NaN
# 121129           NaN      NaN           NaN      NaN
#
# [1345 rows x 40 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'pesos', 'país_extraído',
#        'país_extraído_sin_espacios', 'provincia_extraída',
#        'provincia_extraída_sin_espacios', 'provincia_original_sin_espacios',
#        'localidad_extraída', 'localidad_extraída_sin_espacios',
#        'localidad_original_sin_espacios', 'extraído', 'lat_extraída',
#        'dif_lat', 'lon_extraída', 'dif_lon'],
#       dtype='object')

# %%
sns.countplot(data=data.loc[data.rooms>10],x="rooms")
# Out:
# <AxesSubplot:xlabel='rooms', ylabel='count'>

# %%
data.rooms.mean(),data.rooms.median(),data.rooms.quantile(0.25),data.rooms.quantile(0.75)
# Out:
# (3.080839839628614, 3.0, 2.0, 4.0)

# %%
data.rooms.isnull().sum()
# Out:
# 73830

# %%
data[data.rooms==20].description
# Out:
# 6355      Corredor Responsable: DANIELA E. CASTRO - CPCP...
# 21129     Inmobiliaria De La Via, VENDE, complejo de dep...
# 41083     Corredor Responsable: Marcos Provvidenti - CCI...
# 41227     Corredor Responsable: Mariana Carrizo - CPCPI:...
# 57070     Corredor Responsable: Mariana Carrizo - CPCPI:...
# 114631    DEPARTAMENTOS DE 100 MT2 LOS DE 2 DORMITORIOS ...
# 114810    Vendo Casa en Parque Siquimán. Apurado, Urgent...
# 115162     CASA DE 3 DORMITORIOS CON PLACARES - COCINA C...
# 115170    Inmejorable entorno, hermosa vista natural, gr...
# 115178    "LA HUERTA"A LA VENTA LISTO PARA COMENZARA FUN...
# 115813    VENDO HERMOSA CASA DE DOS PLANTAS-Bº Dean Fune...
# Name: description, dtype: object

# %%
data.rooms.value_counts()
# Out:
# 3.0     12567
# 2.0     12433
# 4.0      7937
# 1.0      7377
# 5.0      3782
# 6.0      1403
# 7.0       770
# 8.0       409
# 10.0      226
# 9.0       184
# 11.0       72
# 12.0       65
# 13.0       33
# 14.0       27
# 15.0       26
# 17.0       16
# 16.0       11
# 20.0       11
# 22.0        8
# 18.0        6
# 21.0        5
# 30.0        4
# 25.0        4
# 19.0        4
# 32.0        3
# 23.0        2
# 24.0        1
# 27.0        1
# 29.0        1
# 31.0        1
# 28.0        1
# Name: rooms, dtype: int64

# %%
import re
import numpy as np
import pandas as pd
pattern_mono="monoambiente|Monoambiente|MONOAMBIENTE"
pattern_mono_regex=re.compile(pattern_mono)
pattern_mono_match=data["description"].apply(lambda x: x if x is np.NaN else pattern_mono_regex.search(x))
print(pattern_mono_match.isnull().sum(),pattern_mono_match.notnull().sum())
pattern_mono_match_not_null=pattern_mono_match.notnull()
data[pattern_mono_match_not_null].index
data.loc[pattern_mono_match_not_null, "Ambientes"] = pattern_mono_match[pattern_mono_match_not_null].apply(lambda x: x.group(0))
#data[pattern_mono_match_not_null]["rooms"].value_counts()
#De los 12.369 con viento a favor podríamos llenar 1.345.
# Out:
# 113880 7340

# %%
#pattern_amb="(?P<cant_ambientes>\d?\d)(.)(amb)"
pattern_amb="(?P<cant_ambientes>\d?\d)(.)(amb|AMB|Amb)"
pattern_amb_regex=re.compile(pattern_amb)
pattern_amb_match=data["description"].apply(lambda x: x if x is np.NaN else pattern_amb_regex.search(x))
print(pattern_amb_match.isnull().sum(),pattern_amb_match.notnull().sum())
pattern_amb_match_not_null=pattern_amb_match.notnull()
data.loc[pattern_amb_match_not_null, "Ambientes"] = pattern_amb_match[pattern_amb_match_not_null].apply(lambda x: x.group("cant_ambientes"))
# Out:
# 83641 37579

# %%
data.Ambientes.notna().sum()
# Out:
# 43785

# %%
data.Ambientes.value_counts()
# Out:
# 2               12916
# 3               12278
# 4                6762
# 1                2701
# monoambiente     2686
#                 ...
# 65                  1
# 52                  1
# 81                  1
# 86                  1
# 54                  1
# Name: Ambientes, Length: 63, dtype: int64

# %%
data.loc[pattern_amb_match_not_null,"Ambientes"]
# Out:
# 0         2
# 2         2
# 3         3
# 11        1
# 12        2
#          ..
# 121127    2
# 121131    4
# 121138    2
# 121139    3
# 121218    2
# Name: Ambientes, Length: 37579, dtype: object

# %%
data.drop("Ambientes",axis=1,inplace=True)
data.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail', 'pesos', 'país_extraído',
#        'país_extraído_sin_espacios', 'provincia_extraída',
#        'provincia_extraída_sin_espacios', 'provincia_original_sin_espacios',
#        'localidad_extraída', 'localidad_extraída_sin_espacios',
#        'localidad_original_sin_espacios', 'extraído', 'lat_extraída',
#        'dif_lat', 'lon_extraída', 'dif_lon'],
#       dtype='object')

# %%
def filtro_tipo_metros_cub(tipo_de_propiedad,metros_cubiertos):
    return data.loc[(data.property_type==tipo_de_propiedad)&(data.surface_covered_in_m2>=metros_cubiertos)]

# %%
data[data.property_type=="apartment"].surface_covered_in_m2.describe()
# Out:
# count     59735.000000
# mean         74.039173
# std         805.139125
# min           0.000000
# 25%          40.000000
# 50%          52.000000
# 75%          76.000000
# max      187000.000000
# Name: surface_covered_in_m2, dtype: float64

# %%
data[data.property_type=="store"].surface_covered_in_m2.describe()
# Out:
# count     3155.000000
# mean       420.389223
# std       1562.609045
# min          1.000000
# 25%         42.000000
# 50%        120.000000
# 75%        300.000000
# max      35000.000000
# Name: surface_covered_in_m2, dtype: float64

# %%
data[data.property_type=="house"].surface_covered_in_m2.describe()
# Out:
# count    33510.000000
# mean       217.844942
# std        420.279500
# min          1.000000
# 25%        120.000000
# 50%        180.000000
# 75%        260.000000
# max      38240.000000
# Name: surface_covered_in_m2, dtype: float64

# %%
(260-120)*1.5+260
# Out:
# 470.0

# %%
120-(260-120)*1.5
# Out:
# -90.0

# %%
filtro_tipo_metros_cub("house",470)
# Out:
#         Unnamed: 0 operation property_type     place_name  \
# 58              58      sell         house       Acassuso
# 78              78      sell         house        Posadas
# 105            105      sell         house       Martínez
# 106            106      sell         house       Acassuso
# 107            107      sell         house       Acassuso
# ...            ...       ...           ...            ...
# 120566      120566      sell         house  Villa Allende
# 120645      120645      sell         house        Córdoba
# 120659      120659      sell         house  Villa Allende
# 120673      120673      sell         house        Córdoba
# 121213      121213      sell         house       Martínez
#
#                                   place_with_parent_names country_name  \
# 58      |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 78                           |Argentina|Misiones|Posadas|    Argentina
# 105     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 106     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 107     |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# ...                                                   ...          ...
# 120566                  |Argentina|Córdoba|Villa Allende|    Argentina
# 120645                                |Argentina|Córdoba|    Argentina
# 120659                  |Argentina|Córdoba|Villa Allende|    Argentina
# 120673                        |Argentina|Córdoba|Córdoba|    Argentina
# 121213  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
#
#                       state_name  geonames_id                        lat-lon  \
# 58      Bs.As. G.B.A. Zona Norte    3436508.0   -34.4739708766,-58.496611619
# 78                      Misiones    3429886.0  -27.3554665957,-55.9021115026
# 105     Bs.As. G.B.A. Zona Norte    3430813.0                            nan
# 106     Bs.As. G.B.A. Zona Norte    3436508.0                            nan
# 107     Bs.As. G.B.A. Zona Norte    3436508.0                            nan
# ...                          ...          ...                            ...
# 120566                   Córdoba    3832815.0                            nan
# 120645                   Córdoba    3860255.0                            nan
# 120659                   Córdoba    3832815.0                            nan
# 120673                   Córdoba    3860259.0                            nan
# 121213  Bs.As. G.B.A. Zona Norte    3430813.0                            nan
#
#               lat  ...  provincia_extraída_sin_espacios  \
# 58     -34.473971  ...         Bs.As. G.B.A. Zona Norte
# 78     -27.355467  ...                         Misiones
# 105           NaN  ...         Bs.As. G.B.A. Zona Norte
# 106           NaN  ...         Bs.As. G.B.A. Zona Norte
# 107           NaN  ...         Bs.As. G.B.A. Zona Norte
# ...           ...  ...                              ...
# 120566        NaN  ...                          Córdoba
# 120645        NaN  ...                          Córdoba
# 120659        NaN  ...                          Córdoba
# 120673        NaN  ...                          Córdoba
# 121213        NaN  ...         Bs.As. G.B.A. Zona Norte
#
#         provincia_original_sin_espacios localidad_extraída  \
# 58             Bs.As. G.B.A. Zona Norte           Acassuso
# 78                             Misiones            Posadas
# 105            Bs.As. G.B.A. Zona Norte           Martínez
# 106            Bs.As. G.B.A. Zona Norte           Acassuso
# 107            Bs.As. G.B.A. Zona Norte           Acassuso
# ...                                 ...                ...
# 120566                          Córdoba      Villa Allende
# 120645                          Córdoba            Córdoba
# 120659                          Córdoba      Villa Allende
# 120673                          Córdoba            Córdoba
# 121213         Bs.As. G.B.A. Zona Norte           Martínez
#
#         localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 58                             Acassuso                         Acassuso
# 78                              Posadas                          Posadas
# 105                            Martínez                         Martínez
# 106                            Acassuso                         Acassuso
# 107                            Acassuso                         Acassuso
# ...                                 ...                              ...
# 120566                    Villa Allende                    Villa Allende
# 120645                          Córdoba                          Córdoba
# 120659                    Villa Allende                    Villa Allende
# 120673                          Córdoba                          Córdoba
# 121213                         Martínez                         Martínez
#
#              extraído  lat_extraída  dif_lat  lon_extraída  dif_lon
# 58           Acassuso    -34.473971      0.0    -58.496612      0.0
# 78            Posadas    -27.355467      0.0    -55.902112      0.0
# 105          Martínez           NaN      NaN           NaN      NaN
# 106          Acassuso           NaN      NaN           NaN      NaN
# 107          Acassuso           NaN      NaN           NaN      NaN
# ...               ...           ...      ...           ...      ...
# 120566  Villa Allende           NaN      NaN           NaN      NaN
# 120645        Córdoba           NaN      NaN           NaN      NaN
# 120659  Villa Allende           NaN      NaN           NaN      NaN
# 120673        Córdoba           NaN      NaN           NaN      NaN
# 121213       Martínez           NaN      NaN           NaN      NaN
#
# [1568 rows x 40 columns]

# %%
data[data.property_type=="PH"].surface_covered_in_m2.describe()
# Out:
# count    4913.000000
# mean       87.659475
# std       138.843642
# min         1.000000
# 25%        51.000000
# 50%        73.000000
# 75%       104.000000
# max      6610.000000
# Name: surface_covered_in_m2, dtype: float64

# %%
sns.scatterplot(data=filtro_tipo_metros_cub("house",5000),x="surface_covered_in_m2",y="price_aprox_usd")
# Out:
# <AxesSubplot:xlabel='surface_covered_in_m2', ylabel='price_aprox_usd'>

# %%
data["precio_m2"]=data.apply(lambda x: np.NaN if x["surface_covered_in_m2"] is np.NaN or x["surface_covered_in_m2"]==0 else x["price_aprox_usd"]/x["surface_covered_in_m2"], axis=1)
datos_filtrados=data.loc[data.property_type=="apartment"]

# %%
data["precio_m2"].describe()
# Out:
# count    8.765800e+04
# mean     3.161714e+03
# std      1.854544e+04
# min      1.510204e+00
# 25%      1.440412e+03
# 50%      2.000000e+03
# 75%      2.758621e+03
# max      2.600000e+06
# Name: precio_m2, dtype: float64

# %%
data.precio_m2.isna().sum()
# Out:
# 33562

# %%
datos_filtrados=(data.loc[np.logical_not((data.surface_covered_in_m2.isnull())|(data.price_aprox_usd.isnull())|(data.surface_covered_in_m2==0))])

# %%
datos_filtrados
# Out:
#         Unnamed: 0 operation property_type       place_name  \
# 0                0      sell            PH        Mataderos
# 2                2      sell     apartment        Mataderos
# 4                4      sell     apartment           Centro
# 6                6      sell            PH            Munro
# 7                7      sell     apartment         Belgrano
# ...            ...       ...           ...              ...
# 121215      121215      sell     apartment         Belgrano
# 121216      121216      sell         house           Beccar
# 121217      121217      sell     apartment    Villa Urquiza
# 121218      121218      sell     apartment      Plaza Colón
# 121219      121219      sell     apartment  Capital Federal
#
#                                   place_with_parent_names country_name  \
# 0                   |Argentina|Capital Federal|Mataderos|    Argentina
# 2                   |Argentina|Capital Federal|Mataderos|    Argentina
# 4       |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 6       |Argentina|Bs.As. G.B.A. Zona Norte|Vicente Ló...    Argentina
# 7                    |Argentina|Capital Federal|Belgrano|    Argentina
# ...                                                   ...          ...
# 121215               |Argentina|Capital Federal|Belgrano|    Argentina
# 121216  |Argentina|Bs.As. G.B.A. Zona Norte|San Isidro...    Argentina
# 121217          |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 121218  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 121219                        |Argentina|Capital Federal|    Argentina
#
#                           state_name  geonames_id  \
# 0                    Capital Federal    3430787.0
# 2                    Capital Federal    3430787.0
# 4       Buenos Aires Costa Atlántica    3435548.0
# 6           Bs.As. G.B.A. Zona Norte    3430511.0
# 7                    Capital Federal    3436077.0
# ...                              ...          ...
# 121215               Capital Federal    3436077.0
# 121216      Bs.As. G.B.A. Zona Norte    3436080.0
# 121217               Capital Federal    3433775.0
# 121218  Buenos Aires Costa Atlántica          NaN
# 121219               Capital Federal    3433955.0
#
#                               lat-lon        lat  ...  \
# 0             -34.6618237,-58.5088387 -34.661824  ...
# 2             -34.6522615,-58.5229825 -34.652262  ...
# 4             -38.0026256,-57.5494468 -38.002626  ...
# 6             -34.5329567,-58.5217825 -34.532957  ...
# 7              -34.5598729,-58.443362 -34.559873  ...
# ...                               ...        ...  ...
# 121215                            nan        NaN  ...
# 121216                            nan        NaN  ...
# 121217  -34.5706388726,-58.4755963355 -34.570639  ...
# 121218                            nan        NaN  ...
# 121219                            nan        NaN  ...
#
#         provincia_original_sin_espacios  localidad_extraída  \
# 0                       Capital Federal           Mataderos
# 2                       Capital Federal           Mataderos
# 4          Buenos Aires Costa Atlántica              Centro
# 6              Bs.As. G.B.A. Zona Norte               Munro
# 7                       Capital Federal            Belgrano
# ...                                 ...                 ...
# 121215                  Capital Federal            Belgrano
# 121216         Bs.As. G.B.A. Zona Norte              Beccar
# 121217                  Capital Federal       Villa Urquiza
# 121218     Buenos Aires Costa Atlántica         Plaza Colón
# 121219                  Capital Federal     Capital Federal
#
#        localidad_extraída_sin_espacios  localidad_original_sin_espacios  \
# 0                            Mataderos                        Mataderos
# 2                            Mataderos                        Mataderos
# 4                               Centro                           Centro
# 6                                Munro                            Munro
# 7                             Belgrano                         Belgrano
# ...                                ...                              ...
# 121215                        Belgrano                         Belgrano
# 121216                          Beccar                           Beccar
# 121217                   Villa Urquiza                    Villa Urquiza
# 121218                     Plaza Colón                      Plaza Colón
# 121219                 Capital Federal                  Capital Federal
#
#                extraído  lat_extraída  dif_lat  lon_extraída  dif_lon  \
# 0             Mataderos    -34.661824      0.0    -58.508839      0.0
# 2             Mataderos    -34.652262      0.0    -58.522982      0.0
# 4                Centro    -38.002626      0.0    -57.549447      0.0
# 6                 Munro    -34.532957      0.0    -58.521782      0.0
# 7              Belgrano    -34.559873      0.0    -58.443362      0.0
# ...                 ...           ...      ...           ...      ...
# 121215         Belgrano           NaN      NaN           NaN      NaN
# 121216           Beccar           NaN      NaN           NaN      NaN
# 121217    Villa Urquiza    -34.570639      0.0    -58.475596      0.0
# 121218      Plaza Colón           NaN      NaN           NaN      NaN
# 121219  Capital Federal           NaN      NaN           NaN      NaN
#
#           precio_m2
# 0       1550.000000
# 2       1309.090909
# 4       1828.571429
# 6       1666.666667
# 7       3450.000000
# ...             ...
# 121215  9354.838710
# 121216  1383.333333
# 121217  3371.794872
# 121218  1997.916667
# 121219  1675.324675
#
# [87658 rows x 41 columns]

# %%
data.precio_m2.notna().sum()
# Out:
# 87658

# %%
sns.violinplot(data=datos_filtrados,y="precio_m2",x="property_type")
# Out:
# <AxesSubplot:xlabel='property_type', ylabel='precio_m2'>

# %%
data.precio_m2.describe()
# Out:
# count    8.765800e+04
# mean     3.161714e+03
# std      1.854544e+04
# min      1.510204e+00
# 25%      1.440412e+03
# 50%      2.000000e+03
# 75%      2.758621e+03
# max      2.600000e+06
# Name: precio_m2, dtype: float64

# %%
2.758621e+03+(2.758621e+03-1.440412e+03)*1.5
# Out:
# 4735.9345

# %%
1.440412e+03-(2.758621e+03-1.440412e+03)*1.5
# Out:
# -536.9015000000002

# %%
data.loc[data.precio_m2>=4735.9345].place_name.value_counts()
# Out:
# Puerto Madero            465
# Boedo                    437
# Palermo                  434
# Belgrano                 294
# Córdoba                  293
#                         ...
# Yerba Buena                1
# Country Club Aranjuez      1
# Aldo Bonzi                 1
# La Punta                   1
# Capilla del Señor          1
# Name: place_name, Length: 315, dtype: int64

# %%
data.groupby(["state_name","property_type"])["precio_m2"].mean()
# Out:
# state_name                    property_type
# Bs.As. G.B.A. Zona Norte      PH                1914.398971
#                               apartment         3283.971559
#                               house             2615.265489
#                               store             4563.725042
# Bs.As. G.B.A. Zona Oeste      PH                2639.989391
#                               apartment         2649.719244
#                               house             2470.597512
#                               store            20093.650154
# Bs.As. G.B.A. Zona Sur        PH                3727.315900
#                               apartment         3466.313126
#                               house             3279.994288
#                               store            15460.213816
# Buenos Aires Costa Atlántica  PH                1320.760276
#                               apartment         2064.723113
#                               house             1484.849490
#                               store             1834.968051
# Buenos Aires Interior         PH                1504.052205
#                               apartment         4105.589058
#                               house             1525.144843
#                               store             1743.401762
# Capital Federal               PH                3362.495764
#                               apartment         3670.267728
#                               house             6051.892619
#                               store             4590.454426
# Catamarca                     apartment         4340.045004
#                               house             1578.280797
# Chaco                         apartment         1696.262705
#                               house              887.221330
#                               store             1220.982511
# Chubut                        PH                        NaN
#                               apartment         2165.101209
#                               house             4304.170217
#                               store             1475.389194
# Corrientes                    PH                1428.884584
#                               apartment         2180.752464
#                               house             1867.805535
#                               store             1896.367490
# Córdoba                       PH                3655.942926
#                               apartment         2918.063369
#                               house             2009.290730
#                               store             2020.302728
# Entre Ríos                    PH                 474.554154
#                               apartment         1532.256088
#                               house             1904.360073
#                               store             1766.578296
# Formosa                       apartment                 NaN
#                               house                     NaN
# Jujuy                         apartment         1212.019509
#                               house             3677.029131
#                               store                     NaN
# La Pampa                      apartment         1844.680411
#                               house              952.393219
#                               store              616.920440
# La Rioja                      apartment                 NaN
#                               house              393.736839
# Mendoza                       PH                1226.216814
#                               apartment         1842.505008
#                               house             3213.128473
#                               store             1301.482738
# Misiones                      PH                        NaN
#                               apartment         1452.945954
#                               house             3277.089854
#                               store               74.655782
# Neuquén                       PH                2562.329436
#                               apartment         2149.596395
#                               house             2412.913200
#                               store             2313.161376
# Río Negro                     PH                2198.161821
#                               apartment         2495.823908
#                               house             2964.321788
#                               store             3091.115103
# Salta                         PH                        NaN
#                               apartment         2811.801211
#                               house             2953.480302
#                               store              448.669400
# San Juan                      apartment         2045.472275
#                               house              940.350861
#                               store                     NaN
# San Luis                      PH                        NaN
#                               apartment         2141.999651
#                               house             4485.179035
#                               store             1370.031257
# Santa Cruz                    apartment                 NaN
#                               house             1168.365020
#                               store              504.753050
# Santa Fe                      PH                1460.472688
#                               apartment         2631.712317
#                               house             1896.691365
#                               store             3718.854532
# Santiago Del Estero           apartment          644.365532
#                               house             1040.000000
# Tierra Del Fuego              apartment         2095.040849
#                               house             1383.761104
#                               store             1329.186654
# Tucumán                       PH                1791.561806
#                               apartment         2727.365637
#                               house             2173.421737
#                               store              609.928063
# Name: precio_m2, dtype: float64

# %%
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)
pd.set_option('max_colwidth', 151)
#warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\anacl\Dropbox\Data Science\DH\TP1\TP1.ipynb Celda 130 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/anacl/Dropbox/Data%20Science/DH/TP1/TP1.ipynb#ch0000140?line=1'>2</a> pd.set_option('display.max_rows', 150)
#       <a href='vscode-notebook-cell:/c%3A/Users/anacl/Dropbox/Data%20Science/DH/TP1/TP1.ipynb#ch0000140?line=2'>3</a> pd.set_option('max_colwidth', 151)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/anacl/Dropbox/Data%20Science/DH/TP1/TP1.ipynb#ch0000140?line=3'>4</a> warnings.filterwarnings('ignore')
#
# NameError: name 'warnings' is not defined
